# %% [markdown]
# ## Constants

# %%
import sys, os
import pandas as pd
import polars as pl
import numpy as np
import subprocess
import gc
import optuna
from datetime import datetime, timezone
import warnings
import xgboost as xgb
import joblib as jl
from sklearn.model_selection import train_test_split
import warnings
from sklearn.metrics import matthews_corrcoef
from mlflow.models import infer_signature
import mlflow
import random
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelBinarizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import StratifiedKFold

today = datetime.now(timezone.utc).strftime("%Y_%m_%d")
warnings.filterwarnings("ignore")

from hyper_params import (
    mushroom_tuning_2024_08_06_1722934727_params,
)

SEED = 108
random.seed(SEED)
N_FOLDS = 10
# model
is_tunning = True
try:
    rs = subprocess.check_output("nvidia-smi")
    device = "cuda" if rs is not None else "cpu"
except (
    Exception
):  # this command not being found can raise quite a few different errors depending on the configuration
    print("No Nvidia GPU in system!")
    device = "cpu"

best_params = {
    "device": device,
    "verbosity": 0,
    "objective": "binary:logistic",
}
best_params.update(mushroom_tuning_2024_08_06_1722934727_params)
best_params
# Out:
# {'device': 'cuda',
#  'verbosity': 0,
#  'objective': 'binary:logistic',
#  'tree_method': 'hist',
#  'eta': 0.0696294726051571,
#  'max_depth': 0,
#  'min_child_weight': 1,
#  'gamma': 0.044230646284796976,
#  'subsample': 0.9405269471473167,
#  'colsample_bytree': 0.2999355523666192,
#  'lambda': 0.9746051811186938,
#  'alpha': 4.210861941737071}

# %% [markdown]
# ## Prepare data

# %%
y_train_pkl = jl.load("../y_train.pkl")
X_train_pkl = jl.load("../X_train.pkl")

print(f"train size: {X_train_pkl.shape}")
# Out:
# train size: (3116945, 294)

# %% [markdown]
# ## CV

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score


clf: xgb.XGBClassifier = xgb.XGBClassifier(
    **best_params,
    n_estimators=4000,
    early_stopping_rounds=50,
    enable_categorical=True,
)

# %%
from tqdm import tqdm

gc.collect()
skf = StratifiedKFold(n_splits=N_FOLDS)

y_preds = []
y_trues = []
for train_index, test_index in tqdm(skf.split(X_train_pkl, y_train_pkl)):
    X_train, X_test = X_train_pkl[train_index], X_train_pkl[test_index]
    y_train, y_test = y_train_pkl[train_index], y_train_pkl[test_index]

    clf.fit(X=X_train, y=y_train, eval_set=[(X_test, y_test)])

    y_pred = clf.predict(X_test)
    y_preds.append(y_pred)
    y_trues.append(y_test)

    del X_train, X_test, y_train, y_test, y_pred
    gc.collect()
# Concatenate the predictions and true labels
y_preds_concat = np.concatenate(y_preds)
y_trues_concat = np.concatenate(y_trues)
mcc = matthews_corrcoef(y_trues_concat, y_preds_concat)
print(f"Validation mcc score: {mcc}")
# Out:
# 0it [00:00, ?it/s]
# [0]	validation_0-logloss:0.62811
# [1]	validation_0-logloss:0.57452
# [2]	validation_0-logloss:0.52929
# [3]	validation_0-logloss:0.49793
# [4]	validation_0-logloss:0.45847
# [5]	validation_0-logloss:0.42435
# [6]	validation_0-logloss:0.40119
# [7]	validation_0-logloss:0.37332
# [8]	validation_0-logloss:0.34690
# [9]	validation_0-logloss:0.32693
# [10]	validation_0-logloss:0.31008
# [11]	validation_0-logloss:0.28907
# [12]	validation_0-logloss:0.27194
# [13]	validation_0-logloss:0.25579
# [14]	validation_0-logloss:0.24169
# [15]	validation_0-logloss:0.22852
# [16]	validation_0-logloss:0.21696
# [17]	validation_0-logloss:0.20686
# [18]	validation_0-logloss:0.19673
# [19]	validation_0-logloss:0.18649
# [20]	validation_0-logloss:0.17683
# [21]	validation_0-logloss:0.16652
# [22]	validation_0-logloss:0.15795
# [23]	validation_0-logloss:0.15191
# [24]	validation_0-logloss:0.14348
# [25]	validation_0-logloss:0.13709
# [26]	validation_0-logloss:0.13271
# [27]	validation_0-logloss:0.12603
# [28]	validation_0-logloss:0.11981
# [29]	validation_0-logloss:0.11492
# [30]	validation_0-logloss:0.10939
# [31]	validation_0-logloss:0.10495
# [32]	validation_0-logloss:0.10023
# [33]	validation_0-logloss:0.09653
# [34]	validation_0-logloss:0.09453
# [35]	validation_0-logloss:0.09078
# [36]	validation_0-logloss:0.08732
# [37]	validation_0-logloss:0.08419
# [38]	validation_0-logloss:0.08078
# [39]	validation_0-logloss:0.07824
# [40]	validation_0-logloss:0.07654
# [41]	validation_0-logloss:0.07454
# [42]	validation_0-logloss:0.07185
# [43]	validation_0-logloss:0.06978
# [44]	validation_0-logloss:0.06786
# [45]	validation_0-logloss:0.06635
# [46]	validation_0-logloss:0.06487
# [47]	validation_0-logloss:0.06292
# [48]	validation_0-logloss:0.06145
# [49]	validation_0-logloss:0.05988
# [50]	validation_0-logloss:0.05862
# [51]	validation_0-logloss:0.05699
# [52]	validation_0-logloss:0.05601
# [53]	validation_0-logloss:0.05515
# [54]	validation_0-logloss:0.05428
# [55]	validation_0-logloss:0.05332
# [56]	validation_0-logloss:0.05240
# [57]	validation_0-logloss:0.05155
# [58]	validation_0-logloss:0.05058
# [59]	validation_0-logloss:0.04982
# [60]	validation_0-logloss:0.04908
# [61]	validation_0-logloss:0.04830
# [62]	validation_0-logloss:0.04776
# [63]	validation_0-logloss:0.04711
# [64]	validation_0-logloss:0.04636
# [65]	validation_0-logloss:0.04567
# [66]	validation_0-logloss:0.04507
# [67]	validation_0-logloss:0.04456
# [68]	validation_0-logloss:0.04409
# [69]	validation_0-logloss:0.04356
# [70]	validation_0-logloss:0.04316
# [71]	validation_0-logloss:0.04279
# [72]	validation_0-logloss:0.04239
# [73]	validation_0-logloss:0.04212
# [74]	validation_0-logloss:0.04181
# [75]	validation_0-logloss:0.04156
# [76]	validation_0-logloss:0.04116
# [77]	validation_0-logloss:0.04090
# [78]	validation_0-logloss:0.04065
# [79]	validation_0-logloss:0.04042
# [80]	validation_0-logloss:0.04025
# [81]	validation_0-logloss:0.03997
# [82]	validation_0-logloss:0.03980
# [83]	validation_0-logloss:0.03962
# [84]	validation_0-logloss:0.03946
# [85]	validation_0-logloss:0.03922
# [86]	validation_0-logloss:0.03903
# [87]	validation_0-logloss:0.03882
# [88]	validation_0-logloss:0.03864
# [89]	validation_0-logloss:0.03851
# [90]	validation_0-logloss:0.03835
# [91]	validation_0-logloss:0.03827
# [92]	validation_0-logloss:0.03816
# [93]	validation_0-logloss:0.03801
# [94]	validation_0-logloss:0.03789
# [95]	validation_0-logloss:0.03779
# [96]	validation_0-logloss:0.03770
# [97]	validation_0-logloss:0.03758
# [98]	validation_0-logloss:0.03751
# [99]	validation_0-logloss:0.03744
# [100]	validation_0-logloss:0.03735
# [101]	validation_0-logloss:0.03728
# [102]	validation_0-logloss:0.03725
# [103]	validation_0-logloss:0.03717
# [104]	validation_0-logloss:0.03708
# [105]	validation_0-logloss:0.03701
# [106]	validation_0-logloss:0.03694
# [107]	validation_0-logloss:0.03687
# [108]	validation_0-logloss:0.03683
# [109]	validation_0-logloss:0.03676
# [110]	validation_0-logloss:0.03673
# [111]	validation_0-logloss:0.03667
# [112]	validation_0-logloss:0.03662
# [113]	validation_0-logloss:0.03658
# [114]	validation_0-logloss:0.03652
# [115]	validation_0-logloss:0.03648
# [116]	validation_0-logloss:0.03645
# [117]	validation_0-logloss:0.03642
# [118]	validation_0-logloss:0.03639
# [119]	validation_0-logloss:0.03636
# [120]	validation_0-logloss:0.03634
# [121]	validation_0-logloss:0.03631
# [122]	validation_0-logloss:0.03629
# [123]	validation_0-logloss:0.03627
# [124]	validation_0-logloss:0.03624
# [125]	validation_0-logloss:0.03620
# [126]	validation_0-logloss:0.03617
# [127]	validation_0-logloss:0.03616
# [128]	validation_0-logloss:0.03614
# [129]	validation_0-logloss:0.03613
# [130]	validation_0-logloss:0.03612
# [131]	validation_0-logloss:0.03608
# [132]	validation_0-logloss:0.03607
# [133]	validation_0-logloss:0.03606
# [134]	validation_0-logloss:0.03605
# [135]	validation_0-logloss:0.03602
# [136]	validation_0-logloss:0.03601
# [137]	validation_0-logloss:0.03600
# [138]	validation_0-logloss:0.03600
# [139]	validation_0-logloss:0.03600
# [140]	validation_0-logloss:0.03598
# [141]	validation_0-logloss:0.03596
# [142]	validation_0-logloss:0.03595
# [143]	validation_0-logloss:0.03593
# [144]	validation_0-logloss:0.03592
# [145]	validation_0-logloss:0.03591
# [146]	validation_0-logloss:0.03591
# [147]	validation_0-logloss:0.03589
# [148]	validation_0-logloss:0.03588
# [149]	validation_0-logloss:0.03588
# [150]	validation_0-logloss:0.03587
# [151]	validation_0-logloss:0.03586
# [152]	validation_0-logloss:0.03585
# [153]	validation_0-logloss:0.03585
# [154]	validation_0-logloss:0.03584
# [155]	validation_0-logloss:0.03584
# [156]	validation_0-logloss:0.03582
# [157]	validation_0-logloss:0.03581
# [158]	validation_0-logloss:0.03581
# [159]	validation_0-logloss:0.03579
# [160]	validation_0-logloss:0.03579
# [161]	validation_0-logloss:0.03579
# [162]	validation_0-logloss:0.03579
# [163]	validation_0-logloss:0.03578
# [164]	validation_0-logloss:0.03577
# [165]	validation_0-logloss:0.03576
# [166]	validation_0-logloss:0.03576
# [167]	validation_0-logloss:0.03575
# [168]	validation_0-logloss:0.03575
# [169]	validation_0-logloss:0.03575
# [170]	validation_0-logloss:0.03575
# [171]	validation_0-logloss:0.03574
# [172]	validation_0-logloss:0.03574
# [173]	validation_0-logloss:0.03574
# [174]	validation_0-logloss:0.03573
# [175]	validation_0-logloss:0.03573
# [176]	validation_0-logloss:0.03572
# [177]	validation_0-logloss:0.03573
# [178]	validation_0-logloss:0.03573
# [179]	validation_0-logloss:0.03572
# [180]	validation_0-logloss:0.03572
# [181]	validation_0-logloss:0.03572
# [182]	validation_0-logloss:0.03572
# [183]	validation_0-logloss:0.03572
# [184]	validation_0-logloss:0.03572
# [185]	validation_0-logloss:0.03572
# [186]	validation_0-logloss:0.03572
# [187]	validation_0-logloss:0.03571
# [188]	validation_0-logloss:0.03571
# [189]	validation_0-logloss:0.03571
# [190]	validation_0-logloss:0.03571
# [191]	validation_0-logloss:0.03571
# [192]	validation_0-logloss:0.03571
# [193]	validation_0-logloss:0.03570
# [194]	validation_0-logloss:0.03570
# [195]	validation_0-logloss:0.03570
# [196]	validation_0-logloss:0.03570
# [197]	validation_0-logloss:0.03570
# [198]	validation_0-logloss:0.03569
# [199]	validation_0-logloss:0.03569
# [200]	validation_0-logloss:0.03569
# [201]	validation_0-logloss:0.03569
# [202]	validation_0-logloss:0.03569
# [203]	validation_0-logloss:0.03569
# [204]	validation_0-logloss:0.03569
# [205]	validation_0-logloss:0.03569
# [206]	validation_0-logloss:0.03568
# [207]	validation_0-logloss:0.03568
# [208]	validation_0-logloss:0.03568
# [209]	validation_0-logloss:0.03568
# [210]	validation_0-logloss:0.03568
# [211]	validation_0-logloss:0.03568
# [212]	validation_0-logloss:0.03568
# [213]	validation_0-logloss:0.03567
# [214]	validation_0-logloss:0.03567
# [215]	validation_0-logloss:0.03567
# [216]	validation_0-logloss:0.03567
# [217]	validation_0-logloss:0.03567
# [218]	validation_0-logloss:0.03567
# [219]	validation_0-logloss:0.03567
# [220]	validation_0-logloss:0.03567
# [221]	validation_0-logloss:0.03568
# [222]	validation_0-logloss:0.03568
# [223]	validation_0-logloss:0.03568
# [224]	validation_0-logloss:0.03567
# [225]	validation_0-logloss:0.03567
# [226]	validation_0-logloss:0.03567
# [227]	validation_0-logloss:0.03568
# [228]	validation_0-logloss:0.03568
# [229]	validation_0-logloss:0.03567
# [230]	validation_0-logloss:0.03567
# [231]	validation_0-logloss:0.03567
# [232]	validation_0-logloss:0.03566
# [233]	validation_0-logloss:0.03566
# [234]	validation_0-logloss:0.03567
# [235]	validation_0-logloss:0.03567
# [236]	validation_0-logloss:0.03567
# [237]	validation_0-logloss:0.03567
# [238]	validation_0-logloss:0.03567
# [239]	validation_0-logloss:0.03567
# [240]	validation_0-logloss:0.03567
# [241]	validation_0-logloss:0.03567
# [242]	validation_0-logloss:0.03567
# [243]	validation_0-logloss:0.03567
# [244]	validation_0-logloss:0.03567
# [245]	validation_0-logloss:0.03567
# [246]	validation_0-logloss:0.03567
# [247]	validation_0-logloss:0.03567
# [248]	validation_0-logloss:0.03567
# [249]	validation_0-logloss:0.03567
# [250]	validation_0-logloss:0.03567
# [251]	validation_0-logloss:0.03567
# [252]	validation_0-logloss:0.03567
# [253]	validation_0-logloss:0.03567
# [254]	validation_0-logloss:0.03567
# [255]	validation_0-logloss:0.03567
# [256]	validation_0-logloss:0.03567
# [257]	validation_0-logloss:0.03567
# [258]	validation_0-logloss:0.03567
# [259]	validation_0-logloss:0.03566
# [260]	validation_0-logloss:0.03567
# [261]	validation_0-logloss:0.03568
# [262]	validation_0-logloss:0.03568
# [263]	validation_0-logloss:0.03568
# [264]	validation_0-logloss:0.03568
# [265]	validation_0-logloss:0.03568
# [266]	validation_0-logloss:0.03567
# [267]	validation_0-logloss:0.03567
# [268]	validation_0-logloss:0.03567
# [269]	validation_0-logloss:0.03567
# [270]	validation_0-logloss:0.03567
# [271]	validation_0-logloss:0.03567
# [272]	validation_0-logloss:0.03567
# [273]	validation_0-logloss:0.03567
# [274]	validation_0-logloss:0.03567
# [275]	validation_0-logloss:0.03567
# [276]	validation_0-logloss:0.03567
# [277]	validation_0-logloss:0.03567
# [278]	validation_0-logloss:0.03568
# [279]	validation_0-logloss:0.03568
# [280]	validation_0-logloss:0.03568
# [281]	validation_0-logloss:0.03568
# [282]	validation_0-logloss:0.03568
# [283]	validation_0-logloss:0.03568
# 1it [01:03, 63.76s/it]
# [0]	validation_0-logloss:0.62978
# [1]	validation_0-logloss:0.57598
# [2]	validation_0-logloss:0.53064
# [3]	validation_0-logloss:0.49916

# %%
submit_df = jl.load("../submit_df.pkl")
X_test_pkl = jl.load("../X_test.pkl")
lb = jl.load("../lb.pkl")

# %%
y_preds = clf.predict(X_test_pkl)
pred_classes = lb.inverse_transform(y_preds)
submit_df["class"] = pred_classes
submit_df.to_csv("submission.csv", index=False)
