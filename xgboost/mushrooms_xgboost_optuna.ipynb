# %% [markdown]
# ## Constants

# %%
import sys, os
import pandas as pd
import numpy as np
import subprocess
import gc
import optuna
from datetime import datetime, timezone
import warnings
import xgboost as xgb
import joblib as jl
from sklearn.model_selection import train_test_split
import warnings
from sklearn.metrics import matthews_corrcoef
from mlflow.models import infer_signature
import mlflow
import random
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelBinarizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import StratifiedKFold

today = datetime.now(timezone.utc).strftime("%Y_%m_%d")
warnings.filterwarnings("ignore")

from hyper_params import (
    mushroom_tuning_2024_08_06_1722934727_params,
)

# helpers
from helpers.loss_functions import *
from helpers.mlflow import *


SEED = 108
random.seed(SEED)
N_FOLDS = 20
# data
train_path = "../../data/mushrooms/train.csv"
test_path = "../../data/mushrooms/test.csv"
cache_path = "../../data/mushrooms/cache"
# model
is_tunning = True
SEED = 108
random.seed(SEED)
N_FOLDS = 3
# data
train_path = "../data/mushrooms/train.csv"
test_path = "../data/mushrooms/test.csv"
cache_path = "../data/mushrooms/cache"
# model
is_tunning = True
try:
    rs = subprocess.check_output("nvidia-smi")
    device = "cuda" if rs is not None else "cpu"
except (
    Exception
):  # this command not being found can raise quite a few different errors depending on the configuration
    print("No Nvidia GPU in system!")
    device = "cpu"
goal = "binary:logistic"

# custom metric
objective_dict = {
    "binary:logistic": {
        "metric": {
            "is_custom": False,
            "name": "logloss",
            "fval": None,
        },
        "direction": "minimize",
    }
}
# objective_dict = {
#     "binary:logistic": {
#         "metric": {
#             "is_custom": True,
#             "name": "MCC",
#             "fval": mcc_metric_v2,
#         },
#         "direction": "maximize",
#     }
# }
metric = objective_dict[goal]["metric"]["name"]
is_custom_metric = objective_dict[goal]["metric"]["is_custom"]
fval = objective_dict[goal]["metric"]["fval"]
direction = objective_dict[goal]["direction"]

best_params = {
    "device": device,
    "verbosity": 0,
    "objective": goal,
}
# best_params.update(mushroom_tuning_2024_08_06_1722934727_params)
best_params

# %% [markdown]
# ## Prepare data

# %%
train = pd.read_csv(train_path)
print(f"train size: {train.shape}")
test = pd.read_csv(test_path)
print(f"test size: {test.shape}")

# %%
target = "class"

categorical_cols = (
    train.drop(columns=target).select_dtypes(include="object").columns.to_list()
)
for c in categorical_cols:
    train[c] = train[c].astype("category")
    test[c] = test[c].astype("category")
numerical_cols = (
    train.drop(columns="id").select_dtypes(include="number").columns.to_list()
)

# %%
# X_train, X_val, y_train, y_val = train_test_split(
#     train.drop(columns=target),
#     train[target],
#     test_size=0.2,
#     random_state=42,
#     stratify=train[target],
# )
X_test = test
X_train = train.drop(columns=target)
y_train = train[target]
gc.collect()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(font_scale=1.5)
X_train['cap-shape'].value_counts().sort_values().plot(kind='barh',figsize=(10, 8))
plt.xlabel("Count", labelpad=14)
plt.ylabel("Label", labelpad=14)
plt.title("Orginal Label for product column", y=1.02)

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler

weird_columns = [
    "cap-shape",
    "cap-surface",
    "cap-color",
    "gill-attachment",
    "gill-spacing",
    "gill-color",
    "veil-type",
    "veil-color",
    "has-ring",
    "ring-type",
    "spore-print-color",
    "habitat",
    "does-bruise-or-bleed",
    "stem-root",
    "stem-surface",
    "stem-color",
]

for col in weird_columns:
    allowed_vals = test[col].unique()
    train.loc[~train[col].isin(allowed_vals), col] = np.nan
    test.loc[~test[col].isin(allowed_vals), col] = np.nan


# Create the numerical and categorical pipelines
numerical_pipeline = Pipeline(
    steps=[
        ("num_imputer", SimpleImputer(strategy="mean")),
        ("scaler", StandardScaler()),
        ("minmax", MinMaxScaler()),
    ]
)

categorical_pipeline = Pipeline(
    steps=[
        ("cat_imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown="ignore")),
    ]
)

# Combine the pipelines into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numerical_pipeline, numerical_cols),
        ("cat", categorical_pipeline, categorical_cols),
    ]
)

# Create the full pipeline with the XGBoost model
data_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
    ]
)

# Preprocess the data
X_train_transformed = data_pipeline.fit_transform(X_train)
X_test_transformed = data_pipeline.transform(X_test)
# X_val_transformed = preprocessor.transform(X_val)
# Binarize the target labels
lb = LabelBinarizer()

y_train_binarized = lb.fit_transform(y_train)
# y_val_binarized = lb.transform(y_val)

# prepare data for training
dtrain = xgb.DMatrix(X_train_transformed, label=y_train_binarized)
# dval = xgb.DMatrix(X_val_transformed, label=y_val_binarized)
dtest = xgb.DMatrix(X_test_transformed)

gc.collect()

# %% [markdown]
# ## CV

# %%
from tqdm import tqdm


def objective(trial):
    skf = StratifiedKFold(n_splits=N_FOLDS)

    # kf = KFold(n_splits=N_FOLDS)
    y_preds = []
    y_trues = []
    hyper_parameters = {
        **best_params,
        **{
            "objective": goal,
            "tree_method": "gpu_hist",
            "eta": trial.suggest_float("eta", 0.001, 0.1),  # 4
            "max_depth": trial.suggest_int("max_depth", 0, 15),  # 3
            "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
            "gamma": trial.suggest_float("gamma", 0.001, 0.1),  # 2
            "subsample": trial.suggest_float("subsample", 0.1, 1),  # 1
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.1, 1),
            "lambda": trial.suggest_float("lambda", 0.001, 10),
            "alpha": trial.suggest_float("alpha", 0.001, 10),
        },
    }
    for train_index, test_index in tqdm(
        skf.split(X_train_transformed, y_train_binarized)
    ):
        X_train, X_test = (
            X_train_transformed[train_index],
            X_train_transformed[test_index],
        )
        y_train, y_test = y_train_binarized[train_index], y_train_binarized[test_index]

        # prepare data for training
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dval = xgb.DMatrix(X_test, label=y_test)
        clf = xgb.train(
            params=hyper_parameters,
            dtrain=dtrain,
            num_boost_round=2000,
            evals=[(dval, "eval")],
            early_stopping_rounds=100,
        )
        y_pred = clf.predict(dval)
        y_pred = (y_pred > 0.51).astype(int)
        y_preds.append(y_pred)
        y_trues.append(y_test)
    # Concatenate the predictions and true labels
    y_preds_concat = np.concatenate(y_preds)
    y_trues_concat = np.concatenate(y_trues)
    mcc = matthews_corrcoef(y_trues_concat, y_preds_concat)
    return mcc


# Create or load a study
today = datetime.now(timezone.utc).strftime("%Y_%m_%d")
curr_timestamp = int(datetime.now(timezone.utc).timestamp())
study_name = f"study_{today}_{curr_timestamp}"
study = optuna.create_study(
    study_name=study_name,
    storage=f"sqlite:///{study_name}.db",
    direction="maximize",
    load_if_exists=True,
)
study.optimize(objective, n_trials=100, timeout=None, show_progress_bar=True)
# Print best trial
best_trial = study.best_trial
print("Best trial:")
print(f" {metric}:", best_trial.value)
print("  Params: ")
for key, value in best_trial.params.items():
    print("    {}: {}".format(key, value))
study_best_params = study.best_params
best_params.update(study_best_params)
jl.dump(best_params, "best_params.pkl")
# Out:
# [I 2024-08-09 01:03:11,440] A new study created in RDB with name: study_2024_08_08_1723140191
#   0%|          | 0/100 [00:00<?, ?it/s]
# [0]	eval-logloss:0.64381
# [1]	eval-logloss:0.60729
# [2]	eval-logloss:0.56756
# [3]	eval-logloss:0.54082
# [4]	eval-logloss:0.51093
# [5]	eval-logloss:0.48768
# [6]	eval-logloss:0.45452
# [7]	eval-logloss:0.43055
# [8]	eval-logloss:0.40829
# [9]	eval-logloss:0.38581
# [10]	eval-logloss:0.36420
# [11]	eval-logloss:0.34223
# [12]	eval-logloss:0.32337
# [13]	eval-logloss:0.30806
# [14]	eval-logloss:0.29402
# [15]	eval-logloss:0.28161
# [16]	eval-logloss:0.27234
# [17]	eval-logloss:0.26417
# [18]	eval-logloss:0.25369
# [19]	eval-logloss:0.24702
# [20]	eval-logloss:0.23955
# [21]	eval-logloss:0.23182
# [22]	eval-logloss:0.22641
# [23]	eval-logloss:0.22027
# [24]	eval-logloss:0.21480
# [25]	eval-logloss:0.20722
# [26]	eval-logloss:0.20321
# [27]	eval-logloss:0.19913
# [28]	eval-logloss:0.19428
# [29]	eval-logloss:0.18627
# [30]	eval-logloss:0.18284
# [31]	eval-logloss:0.17936
# [32]	eval-logloss:0.17620
# [33]	eval-logloss:0.16844
# [34]	eval-logloss:0.16526
# [35]	eval-logloss:0.15888
# [36]	eval-logloss:0.15570
# [37]	eval-logloss:0.15025
# [38]	eval-logloss:0.14854
# [39]	eval-logloss:0.14240
# [40]	eval-logloss:0.14070
# [41]	eval-logloss:0.13844
# [42]	eval-logloss:0.13465
# [43]	eval-logloss:0.13111
# [44]	eval-logloss:0.12644
# [45]	eval-logloss:0.12232
# [46]	eval-logloss:0.12041
# [47]	eval-logloss:0.11885
# [48]	eval-logloss:0.11716
# [49]	eval-logloss:0.11556
# [50]	eval-logloss:0.11330
# [51]	eval-logloss:0.11193
# [52]	eval-logloss:0.11031
# [53]	eval-logloss:0.10875
# [54]	eval-logloss:0.10726
# [55]	eval-logloss:0.10557
# [56]	eval-logloss:0.10457
# [57]	eval-logloss:0.10394
# [58]	eval-logloss:0.10258
# [59]	eval-logloss:0.10152
# [60]	eval-logloss:0.09995
# [61]	eval-logloss:0.09913
# [62]	eval-logloss:0.09780
# [63]	eval-logloss:0.09679
# [64]	eval-logloss:0.09569
# [65]	eval-logloss:0.09475
# [66]	eval-logloss:0.09368
# [67]	eval-logloss:0.09283
# [68]	eval-logloss:0.09008
# [69]	eval-logloss:0.08907
# [70]	eval-logloss:0.08868
# [71]	eval-logloss:0.08797
# [72]	eval-logloss:0.08666
# [73]	eval-logloss:0.08487
# [74]	eval-logloss:0.08422
# [75]	eval-logloss:0.08317
# [76]	eval-logloss:0.08265
# [77]	eval-logloss:0.08209
# [78]	eval-logloss:0.08097
# [79]	eval-logloss:0.08035
# [80]	eval-logloss:0.07953
# [81]	eval-logloss:0.07880
# [82]	eval-logloss:0.07797
# [83]	eval-logloss:0.07748
# [84]	eval-logloss:0.07704
# [85]	eval-logloss:0.07666
# [86]	eval-logloss:0.07584
# [87]	eval-logloss:0.07471
# [88]	eval-logloss:0.07381
# [89]	eval-logloss:0.07313
# [90]	eval-logloss:0.07200
# [91]	eval-logloss:0.07164
# [92]	eval-logloss:0.07121
# [93]	eval-logloss:0.07060
# [94]	eval-logloss:0.06997
# [95]	eval-logloss:0.06976
# [96]	eval-logloss:0.06898
# [97]	eval-logloss:0.06866
# [98]	eval-logloss:0.06809
# [99]	eval-logloss:0.06727
# [100]	eval-logloss:0.06675
# [101]	eval-logloss:0.06598
# [102]	eval-logloss:0.06569
# [103]	eval-logloss:0.06553
# [104]	eval-logloss:0.06511
# [105]	eval-logloss:0.06458
# [106]	eval-logloss:0.06415
# [107]	eval-logloss:0.06343
# [108]	eval-logloss:0.06285
# [109]	eval-logloss:0.06268
# [110]	eval-logloss:0.06238
# [111]	eval-logloss:0.06206
# [112]	eval-logloss:0.06164
# [113]	eval-logloss:0.06118
# [114]	eval-logloss:0.06081
# [115]	eval-logloss:0.06042
# [116]	eval-logloss:0.06024
# [117]	eval-logloss:0.05984
# [118]	eval-logloss:0.05941
# [119]	eval-logloss:0.05927
# [120]	eval-logloss:0.05890
# [121]	eval-logloss:0.05879
# [122]	eval-logloss:0.05856
# [123]	eval-logloss:0.05824
# [124]	eval-logloss:0.05812
# [125]	eval-logloss:0.05777
# [126]	eval-logloss:0.05770
# [127]	eval-logloss:0.05738
# [128]	eval-logloss:0.05652
# [129]	eval-logloss:0.05645
# [130]	eval-logloss:0.05622
# [131]	eval-logloss:0.05595
# [132]	eval-logloss:0.05583
# [133]	eval-logloss:0.05567
# [134]	eval-logloss:0.05543
# [135]	eval-logloss:0.05536
# [136]	eval-logloss:0.05514
# [137]	eval-logloss:0.05509
# [138]	eval-logloss:0.05494
# [139]	eval-logloss:0.05484
# [140]	eval-logloss:0.05442
# [141]	eval-logloss:0.05419
# [142]	eval-logloss:0.05409
# [143]	eval-logloss:0.05379
# [144]	eval-logloss:0.05335
# [145]	eval-logloss:0.05326
# [146]	eval-logloss:0.05320
# [147]	eval-logloss:0.05299
# [148]	eval-logloss:0.05294
# [149]	eval-logloss:0.05290
# [150]	eval-logloss:0.05284
# [151]	eval-logloss:0.05267
# [152]	eval-logloss:0.05253
# [153]	eval-logloss:0.05222
# [154]	eval-logloss:0.05215
# [155]	eval-logloss:0.05207
# [156]	eval-logloss:0.05186
# [157]	eval-logloss:0.05155
# [158]	eval-logloss:0.05121
# [159]	eval-logloss:0.05101
# [160]	eval-logloss:0.05089
# [161]	eval-logloss:0.05075
# [162]	eval-logloss:0.05027
# [163]	eval-logloss:0.05014
# [164]	eval-logloss:0.04985
# [165]	eval-logloss:0.04944
# [166]	eval-logloss:0.04921
# [167]	eval-logloss:0.04911
# [168]	eval-logloss:0.04901
# [169]	eval-logloss:0.04875
# [170]	eval-logloss:0.04845
# [171]	eval-logloss:0.04835
# [172]	eval-logloss:0.04827
# [173]	eval-logloss:0.04808
# [174]	eval-logloss:0.04803
# [175]	eval-logloss:0.04799
# [176]	eval-logloss:0.04782
# [177]	eval-logloss:0.04754
# [178]	eval-logloss:0.04746
# [179]	eval-logloss:0.04739
# [180]	eval-logloss:0.04736
# [181]	eval-logloss:0.04734
# [182]	eval-logloss:0.04726
# [183]	eval-logloss:0.04721
# [184]	eval-logloss:0.04714
# [185]	eval-logloss:0.04699
# [186]	eval-logloss:0.04687
# [187]	eval-logloss:0.04683
# [188]	eval-logloss:0.04666
# [189]	eval-logloss:0.04659
# [190]	eval-logloss:0.04657
# [191]	eval-logloss:0.04650
# [192]	eval-logloss:0.04639
# [193]	eval-logloss:0.04626
# [194]	eval-logloss:0.04616
# [195]	eval-logloss:0.04603
# [196]	eval-logloss:0.04596
# [197]	eval-logloss:0.04576
# [198]	eval-logloss:0.04568
# [199]	eval-logloss:0.04563
# [200]	eval-logloss:0.04554
# [201]	eval-logloss:0.04547
# [202]	eval-logloss:0.04540
# [203]	eval-logloss:0.04528
# [204]	eval-logloss:0.04525
# [205]	eval-logloss:0.04516
# [206]	eval-logloss:0.04507
# [207]	eval-logloss:0.04503
# [208]	eval-logloss:0.04493
# [209]	eval-logloss:0.04483
# [210]	eval-logloss:0.04474
# [211]	eval-logloss:0.04463
# [212]	eval-logloss:0.04457
# [213]	eval-logloss:0.04450
# [214]	eval-logloss:0.04447
# [215]	eval-logloss:0.04443
# [216]	eval-logloss:0.04432
# [217]	eval-logloss:0.04429
# [218]	eval-logloss:0.04420
# [219]	eval-logloss:0.04409
# [220]	eval-logloss:0.04404
# [221]	eval-logloss:0.04397
# [222]	eval-logloss:0.04393
# [223]	eval-logloss:0.04392
# [224]	eval-logloss:0.04381
# [225]	eval-logloss:0.04376
# [226]	eval-logloss:0.04371
# [227]	eval-logloss:0.04368
# [228]	eval-logloss:0.04365
# [229]	eval-logloss:0.04362
# [230]	eval-logloss:0.04358
# [231]	eval-logloss:0.04351
# [232]	eval-logloss:0.04350
# [233]	eval-logloss:0.04341
# [234]	eval-logloss:0.04333
# [235]	eval-logloss:0.04331
# [236]	eval-logloss:0.04326
# [237]	eval-logloss:0.04319
# [238]	eval-logloss:0.04312
# [239]	eval-logloss:0.04308
# [240]	eval-logloss:0.04302
# [241]	eval-logloss:0.04300
# [242]	eval-logloss:0.04297
# [243]	eval-logloss:0.04291
# [244]	eval-logloss:0.04287
# [245]	eval-logloss:0.04283
# [246]	eval-logloss:0.04280
# [247]	eval-logloss:0.04270
# [248]	eval-logloss:0.04265
# [249]	eval-logloss:0.04260
# [250]	eval-logloss:0.04257
# [251]	eval-logloss:0.04250
# [252]	eval-logloss:0.04247
# [253]	eval-logloss:0.04246
# [254]	eval-logloss:0.04242
# [255]	eval-logloss:0.04237
# [256]	eval-logloss:0.04235
# [257]	eval-logloss:0.04231
# [258]	eval-logloss:0.04226
# [259]	eval-logloss:0.04223
# [260]	eval-logloss:0.04217
# [261]	eval-logloss:0.04214
# [262]	eval-logloss:0.04210
# [263]	eval-logloss:0.04207
# [264]	eval-logloss:0.04203
# [265]	eval-logloss:0.04199
# [266]	eval-logloss:0.04195
# [267]	eval-logloss:0.04192
# [268]	eval-logloss:0.04191
# [269]	eval-logloss:0.04187
# [270]	eval-logloss:0.04184
# [271]	eval-logloss:0.04182
# [272]	eval-logloss:0.04180
# [273]	eval-logloss:0.04179
# [274]	eval-logloss:0.04176
# [275]	eval-logloss:0.04173
# [276]	eval-logloss:0.04172
# [277]	eval-logloss:0.04168
# [278]	eval-logloss:0.04165
# [279]	eval-logloss:0.04163
# [280]	eval-logloss:0.04162
# [281]	eval-logloss:0.04160
# [282]	eval-logloss:0.04156
# [283]	eval-logloss:0.04153
# [284]	eval-logloss:0.04151
# [285]	eval-logloss:0.04148
# [286]	eval-logloss:0.04147
# [287]	eval-logloss:0.04145
# [288]	eval-logloss:0.04144
# [289]	eval-logloss:0.04141
# [290]	eval-logloss:0.04137
# [291]	eval-logloss:0.04132
# [292]	eval-logloss:0.04131
# [293]	eval-logloss:0.04130
# [294]	eval-logloss:0.04124
# [295]	eval-logloss:0.04121
# [296]	eval-logloss:0.04120
# [297]	eval-logloss:0.04116
# [298]	eval-logloss:0.04115
# [299]	eval-logloss:0.04114
# [300]	eval-logloss:0.04112
# [301]	eval-logloss:0.04110
# [302]	eval-logloss:0.04109
# [303]	eval-logloss:0.04107
# [304]	eval-logloss:0.04106
# [305]	eval-logloss:0.04102
# [306]	eval-logloss:0.04101
# [307]	eval-logloss:0.04098
# [308]	eval-logloss:0.04097
# [309]	eval-logloss:0.04094
# [310]	eval-logloss:0.04093
# [311]	eval-logloss:0.04091
# [312]	eval-logloss:0.04090
# [313]	eval-logloss:0.04089
# [314]	eval-logloss:0.04086
# [315]	eval-logloss:0.04085
# [316]	eval-logloss:0.04084
# [317]	eval-logloss:0.04084
# [318]	eval-logloss:0.04080
# [319]	eval-logloss:0.04079
# [320]	eval-logloss:0.04077
# [321]	eval-logloss:0.04075
# [322]	eval-logloss:0.04073
# [323]	eval-logloss:0.04072
# [324]	eval-logloss:0.04071
# [325]	eval-logloss:0.04069
# [326]	eval-logloss:0.04068
# [327]	eval-logloss:0.04066
# [328]	eval-logloss:0.04063
# [329]	eval-logloss:0.04061
# [330]	eval-logloss:0.04060
# [331]	eval-logloss:0.04060
# [332]	eval-logloss:0.04058
# [333]	eval-logloss:0.04058
# [334]	eval-logloss:0.04056
# [335]	eval-logloss:0.04055
# [336]	eval-logloss:0.04054
# [337]	eval-logloss:0.04052
# [338]	eval-logloss:0.04050
# [339]	eval-logloss:0.04050
# [340]	eval-logloss:0.04049
# [341]	eval-logloss:0.04048
# [342]	eval-logloss:0.04047
# [343]	eval-logloss:0.04046
# [344]	eval-logloss:0.04046
# [345]	eval-logloss:0.04044
# [346]	eval-logloss:0.04043
# [347]	eval-logloss:0.04041
# [348]	eval-logloss:0.04041
# [349]	eval-logloss:0.04040
# [350]	eval-logloss:0.04039
# [351]	eval-logloss:0.04038
# [352]	eval-logloss:0.04037
# [353]	eval-logloss:0.04036
# [354]	eval-logloss:0.04035
# [355]	eval-logloss:0.04035
# [356]	eval-logloss:0.04033
# [357]	eval-logloss:0.04033
# [358]	eval-logloss:0.04031
# [359]	eval-logloss:0.04031
# [360]	eval-logloss:0.04030
# [361]	eval-logloss:0.04029
# [362]	eval-logloss:0.04028
# [363]	eval-logloss:0.04028
# [364]	eval-logloss:0.04027
# [365]	eval-logloss:0.04027
# [366]	eval-logloss:0.04026
# [367]	eval-logloss:0.04025
# [368]	eval-logloss:0.04024
# [369]	eval-logloss:0.04024
# [370]	eval-logloss:0.04023
# [371]	eval-logloss:0.04022
# [372]	eval-logloss:0.04021
# [373]	eval-logloss:0.04020
# [374]	eval-logloss:0.04019
# [375]	eval-logloss:0.04018
# [376]	eval-logloss:0.04017
# [377]	eval-logloss:0.04016
# [378]	eval-logloss:0.04014
# [379]	eval-logloss:0.04013
# [380]	eval-logloss:0.04013
# [381]	eval-logloss:0.04012
# [382]	eval-logloss:0.04011
# [383]	eval-logloss:0.04011
# [384]	eval-logloss:0.04011
# [385]	eval-logloss:0.04010
# [386]	eval-logloss:0.04009
# [387]	eval-logloss:0.04008
# [388]	eval-logloss:0.04007
# [389]	eval-logloss:0.04007
# [390]	eval-logloss:0.04006
# [391]	eval-logloss:0.04006
# [392]	eval-logloss:0.04004
# [393]	eval-logloss:0.04003
# [394]	eval-logloss:0.04002
# [395]	eval-logloss:0.04001
# [396]	eval-logloss:0.04001
# [397]	eval-logloss:0.04000
# [398]	eval-logloss:0.04000
# [399]	eval-logloss:0.03999
# [400]	eval-logloss:0.03999
# [401]	eval-logloss:0.03997
# [402]	eval-logloss:0.03997
# [403]	eval-logloss:0.03995
# [404]	eval-logloss:0.03994
# [405]	eval-logloss:0.03994
# [406]	eval-logloss:0.03993
# [407]	eval-logloss:0.03992
# [408]	eval-logloss:0.03992
# [409]	eval-logloss:0.03991
# [410]	eval-logloss:0.03990
# [411]	eval-logloss:0.03989
# [412]	eval-logloss:0.03989
# [413]	eval-logloss:0.03988
# [414]	eval-logloss:0.03987
# [415]	eval-logloss:0.03986
# [416]	eval-logloss:0.03986
# [417]	eval-logloss:0.03985
# [418]	eval-logloss:0.03984
# [419]	eval-logloss:0.03983
# [420]	eval-logloss:0.03983
# [421]	eval-logloss:0.03982
# [422]	eval-logloss:0.03982
# [423]	eval-logloss:0.03982
# [424]	eval-logloss:0.03981
# [425]	eval-logloss:0.03981
# [426]	eval-logloss:0.03981
# [427]	eval-logloss:0.03979
# [428]	eval-logloss:0.03979
# [429]	eval-logloss:0.03979
# [430]	eval-logloss:0.03978
# [431]	eval-logloss:0.03978
# [432]	eval-logloss:0.03978
# [433]	eval-logloss:0.03977
# [434]	eval-logloss:0.03976
# [435]	eval-logloss:0.03976
# [436]	eval-logloss:0.03976
# [437]	eval-logloss:0.03975
# [438]	eval-logloss:0.03975
# [439]	eval-logloss:0.03975
# [440]	eval-logloss:0.03975
# [441]	eval-logloss:0.03975
# [442]	eval-logloss:0.03974
# [443]	eval-logloss:0.03973
# [444]	eval-logloss:0.03973
# [445]	eval-logloss:0.03973
# [446]	eval-logloss:0.03972
# [447]	eval-logloss:0.03972
# [448]	eval-logloss:0.03972
# [449]	eval-logloss:0.03971
# [450]	eval-logloss:0.03970
# [451]	eval-logloss:0.03970
# [452]	eval-logloss:0.03970
# [453]	eval-logloss:0.03970
# [454]	eval-logloss:0.03969
# [455]	eval-logloss:0.03969
# [456]	eval-logloss:0.03968
# [457]	eval-logloss:0.03968
# [458]	eval-logloss:0.03967
# [459]	eval-logloss:0.03967
# [460]	eval-logloss:0.03967
# [461]	eval-logloss:0.03966
# [462]	eval-logloss:0.03966
# [463]	eval-logloss:0.03965
# [464]	eval-logloss:0.03964
# [465]	eval-logloss:0.03964
# [466]	eval-logloss:0.03964
# [467]	eval-logloss:0.03963
# [468]	eval-logloss:0.03963
# [469]	eval-logloss:0.03963
# [470]	eval-logloss:0.03962
# [471]	eval-logloss:0.03962
# [472]	eval-logloss:0.03961
# [473]	eval-logloss:0.03961
# [474]	eval-logloss:0.03961
# [475]	eval-logloss:0.03960
# [476]	eval-logloss:0.03960
# [477]	eval-logloss:0.03960
# [478]	eval-logloss:0.03960
# [479]	eval-logloss:0.03960
# [480]	eval-logloss:0.03960
# [481]	eval-logloss:0.03960
# [482]	eval-logloss:0.03959
# [483]	eval-logloss:0.03959
# [484]	eval-logloss:0.03959
# [485]	eval-logloss:0.03958
# [486]	eval-logloss:0.03958
# [487]	eval-logloss:0.03957
# [488]	eval-logloss:0.03957
# [489]	eval-logloss:0.03957
# [490]	eval-logloss:0.03956
# [491]	eval-logloss:0.03957
# [492]	eval-logloss:0.03956
# [493]	eval-logloss:0.03956
# [494]	eval-logloss:0.03955
# [495]	eval-logloss:0.03955
# [496]	eval-logloss:0.03954
# [497]	eval-logloss:0.03954
# [498]	eval-logloss:0.03953
# [499]	eval-logloss:0.03953
# [500]	eval-logloss:0.03953
# [501]	eval-logloss:0.03953
# [502]	eval-logloss:0.03952
# [503]	eval-logloss:0.03952
# [504]	eval-logloss:0.03952
# [505]	eval-logloss:0.03952
# [506]	eval-logloss:0.03952
# [507]	eval-logloss:0.03952
# [508]	eval-logloss:0.03951
# [509]	eval-logloss:0.03951
# [510]	eval-logloss:0.03949
# [511]	eval-logloss:0.03949
# [512]	eval-logloss:0.03950
# [513]	eval-logloss:0.03950
# [514]	eval-logloss:0.03949
# [515]	eval-logloss:0.03949
# [516]	eval-logloss:0.03949
# [517]	eval-logloss:0.03949
# [518]	eval-logloss:0.03949
# [519]	eval-logloss:0.03948
# [520]	eval-logloss:0.03948
# [521]	eval-logloss:0.03948
# [522]	eval-logloss:0.03947
# [523]	eval-logloss:0.03947
# [524]	eval-logloss:0.03947
# [525]	eval-logloss:0.03947
# [526]	eval-logloss:0.03946
# [527]	eval-logloss:0.03946
# [528]	eval-logloss:0.03946
# [529]	eval-logloss:0.03946
# [530]	eval-logloss:0.03946
# [531]	eval-logloss:0.03946
# [532]	eval-logloss:0.03946
# [533]	eval-logloss:0.03946
# [534]	eval-logloss:0.03946
# [535]	eval-logloss:0.03946
# [536]	eval-logloss:0.03946
# [537]	eval-logloss:0.03947
# [538]	eval-logloss:0.03946
# [539]	eval-logloss:0.03945
# [540]	eval-logloss:0.03945
# [541]	eval-logloss:0.03945
# [542]	eval-logloss:0.03945
# [543]	eval-logloss:0.03945
# [544]	eval-logloss:0.03944
# [545]	eval-logloss:0.03944
# [546]	eval-logloss:0.03943
# [547]	eval-logloss:0.03943
# [548]	eval-logloss:0.03943
# [549]	eval-logloss:0.03943
# [550]	eval-logloss:0.03943
# [551]	eval-logloss:0.03942
# [552]	eval-logloss:0.03942
# [553]	eval-logloss:0.03941
# [554]	eval-logloss:0.03941
# [555]	eval-logloss:0.03941
# [556]	eval-logloss:0.03941
# [557]	eval-logloss:0.03940
# [558]	eval-logloss:0.03940
# [559]	eval-logloss:0.03941
# [560]	eval-logloss:0.03940
# [561]	eval-logloss:0.03939
# [562]	eval-logloss:0.03939
# [563]	eval-logloss:0.03939
# [564]	eval-logloss:0.03938
# [565]	eval-logloss:0.03938
# [566]	eval-logloss:0.03937
# [567]	eval-logloss:0.03937
# [568]	eval-logloss:0.03937
# [569]	eval-logloss:0.03937
# [570]	eval-logloss:0.03937
# [571]	eval-logloss:0.03937
# [572]	eval-logloss:0.03936
# [573]	eval-logloss:0.03937
# [574]	eval-logloss:0.03937
# [575]	eval-logloss:0.03936
# [576]	eval-logloss:0.03936
# [577]	eval-logloss:0.03936
# [578]	eval-logloss:0.03936
# [579]	eval-logloss:0.03935
# [580]	eval-logloss:0.03935
# [581]	eval-logloss:0.03934
# [582]	eval-logloss:0.03934
# [583]	eval-logloss:0.03934
# [584]	eval-logloss:0.03933
# [585]	eval-logloss:0.03933
# [586]	eval-logloss:0.03932
# [587]	eval-logloss:0.03932
# [588]	eval-logloss:0.03932
# [589]	eval-logloss:0.03932
# [590]	eval-logloss:0.03932
# [591]	eval-logloss:0.03931
# [592]	eval-logloss:0.03931
# [593]	eval-logloss:0.03931
# [594]	eval-logloss:0.03931
# [595]	eval-logloss:0.03931
# [596]	eval-logloss:0.03930
# [597]	eval-logloss:0.03931
# [598]	eval-logloss:0.03930
# [599]	eval-logloss:0.03930
# [600]	eval-logloss:0.03930
# [601]	eval-logloss:0.03930
# [602]	eval-logloss:0.03929
# [603]	eval-logloss:0.03929
# [604]	eval-logloss:0.03929
# [605]	eval-logloss:0.03929
# [606]	eval-logloss:0.03928
# [607]	eval-logloss:0.03928
# [608]	eval-logloss:0.03927
# [609]	eval-logloss:0.03927
# [610]	eval-logloss:0.03927
# [611]	eval-logloss:0.03927
# [612]	eval-logloss:0.03926
# [613]	eval-logloss:0.03926
# [614]	eval-logloss:0.03926
# [615]	eval-logloss:0.03926
# [616]	eval-logloss:0.03926
# [617]	eval-logloss:0.03926
# [618]	eval-logloss:0.03925
# [619]	eval-logloss:0.03925
# [620]	eval-logloss:0.03925
# [621]	eval-logloss:0.03925
# [622]	eval-logloss:0.03925
# [623]	eval-logloss:0.03925
# [624]	eval-logloss:0.03925
# [625]	eval-logloss:0.03925
# [626]	eval-logloss:0.03925
# [627]	eval-logloss:0.03924
# [628]	eval-logloss:0.03924
# [629]	eval-logloss:0.03924
# [630]	eval-logloss:0.03924
# [631]	eval-logloss:0.03924
# [632]	eval-logloss:0.03924
# [633]	eval-logloss:0.03924
# [634]	eval-logloss:0.03923
# [635]	eval-logloss:0.03923
# [636]	eval-logloss:0.03922
# [637]	eval-logloss:0.03922
# [638]	eval-logloss:0.03922
# [639]	eval-logloss:0.03922
# [640]	eval-logloss:0.03921
# [641]	eval-logloss:0.03921
# [642]	eval-logloss:0.03921
# [643]	eval-logloss:0.03921
# [644]	eval-logloss:0.03921
# [645]	eval-logloss:0.03921
# [646]	eval-logloss:0.03921
# [647]	eval-logloss:0.03921
# [648]	eval-logloss:0.03920
# [649]	eval-logloss:0.03920
# [650]	eval-logloss:0.03920
# [651]	eval-logloss:0.03919
# [652]	eval-logloss:0.03919
# [653]	eval-logloss:0.03919
# [654]	eval-logloss:0.03918
# [655]	eval-logloss:0.03918
# [656]	eval-logloss:0.03918
# [657]	eval-logloss:0.03918
# [658]	eval-logloss:0.03918
# [659]	eval-logloss:0.03918
# [660]	eval-logloss:0.03918
# [661]	eval-logloss:0.03918
# [662]	eval-logloss:0.03918
# [663]	eval-logloss:0.03918
# [664]	eval-logloss:0.03917
# [665]	eval-logloss:0.03917
# [666]	eval-logloss:0.03917
# [667]	eval-logloss:0.03917
# [668]	eval-logloss:0.03917
# [669]	eval-logloss:0.03917
# [670]	eval-logloss:0.03917
# [671]	eval-logloss:0.03917
# [672]	eval-logloss:0.03917
# [673]	eval-logloss:0.03917
# [674]	eval-logloss:0.03916
# [675]	eval-logloss:0.03916
# [676]	eval-logloss:0.03916
# [677]	eval-logloss:0.03916
# [678]	eval-logloss:0.03915
# [679]	eval-logloss:0.03914
# [680]	eval-logloss:0.03914
# [681]	eval-logloss:0.03913
# [682]	eval-logloss:0.03913
# [683]	eval-logloss:0.03913
# [684]	eval-logloss:0.03913
# [685]	eval-logloss:0.03913
# [686]	eval-logloss:0.03913
# [687]	eval-logloss:0.03914
# [688]	eval-logloss:0.03914
# [689]	eval-logloss:0.03914
# [690]	eval-logloss:0.03913
# [691]	eval-logloss:0.03913
# [692]	eval-logloss:0.03914
# [693]	eval-logloss:0.03913
# [694]	eval-logloss:0.03913
# [695]	eval-logloss:0.03913
# [696]	eval-logloss:0.03913
# [697]	eval-logloss:0.03913
# [698]	eval-logloss:0.03913
# [699]	eval-logloss:0.03913
# [700]	eval-logloss:0.03913
# [701]	eval-logloss:0.03913
# [702]	eval-logloss:0.03913
# [703]	eval-logloss:0.03912
# [704]	eval-logloss:0.03912
# [705]	eval-logloss:0.03912
# [706]	eval-logloss:0.03912
# [707]	eval-logloss:0.03911
# [708]	eval-logloss:0.03912
# [709]	eval-logloss:0.03912
# [710]	eval-logloss:0.03912
# [711]	eval-logloss:0.03912
# [712]	eval-logloss:0.03912
# [713]	eval-logloss:0.03912
# [714]	eval-logloss:0.03912
# [715]	eval-logloss:0.03911
# [716]	eval-logloss:0.03912
# [717]	eval-logloss:0.03911
# [718]	eval-logloss:0.03911
# [719]	eval-logloss:0.03911
# [720]	eval-logloss:0.03911
# [721]	eval-logloss:0.03911
# [722]	eval-logloss:0.03911
# [723]	eval-logloss:0.03911
# [724]	eval-logloss:0.03910
# [725]	eval-logloss:0.03910
# [726]	eval-logloss:0.03910
# [727]	eval-logloss:0.03910
# [728]	eval-logloss:0.03911
# [729]	eval-logloss:0.03910
# [730]	eval-logloss:0.03910
# [731]	eval-logloss:0.03910
# [732]	eval-logloss:0.03910
# [733]	eval-logloss:0.03909
# [734]	eval-logloss:0.03909
# [735]	eval-logloss:0.03909
# [736]	eval-logloss:0.03909
# [737]	eval-logloss:0.03908
# [738]	eval-logloss:0.03908
# [739]	eval-logloss:0.03909
# [740]	eval-logloss:0.03909
# [741]	eval-logloss:0.03909
# [742]	eval-logloss:0.03909
# [743]	eval-logloss:0.03909
# [744]	eval-logloss:0.03909
# [745]	eval-logloss:0.03909
# [746]	eval-logloss:0.03909
# [747]	eval-logloss:0.03908
# [748]	eval-logloss:0.03908
# [749]	eval-logloss:0.03908
# [750]	eval-logloss:0.03908
# [751]	eval-logloss:0.03908
# [752]	eval-logloss:0.03907
# [753]	eval-logloss:0.03907
# [754]	eval-logloss:0.03906
# [755]	eval-logloss:0.03906
# [756]	eval-logloss:0.03907
# [757]	eval-logloss:0.03906
# [758]	eval-logloss:0.03906
# [759]	eval-logloss:0.03906
# [760]	eval-logloss:0.03906
# [761]	eval-logloss:0.03906
# [762]	eval-logloss:0.03906
# [763]	eval-logloss:0.03905
# [764]	eval-logloss:0.03905
# [765]	eval-logloss:0.03905
# [766]	eval-logloss:0.03905
# [767]	eval-logloss:0.03905
# [768]	eval-logloss:0.03905
# [769]	eval-logloss:0.03905
# [770]	eval-logloss:0.03905
# [771]	eval-logloss:0.03905
# [772]	eval-logloss:0.03905
# [773]	eval-logloss:0.03905
# [774]	eval-logloss:0.03905
# [775]	eval-logloss:0.03904
# [776]	eval-logloss:0.03904
# [777]	eval-logloss:0.03904
# [778]	eval-logloss:0.03904
# [779]	eval-logloss:0.03904
# [780]	eval-logloss:0.03904
# [781]	eval-logloss:0.03904
# [782]	eval-logloss:0.03904
# [783]	eval-logloss:0.03903
# [784]	eval-logloss:0.03903
# [785]	eval-logloss:0.03903
# [786]	eval-logloss:0.03903
# [787]	eval-logloss:0.03902
# [788]	eval-logloss:0.03902
# [789]	eval-logloss:0.03902
# [790]	eval-logloss:0.03902
# [791]	eval-logloss:0.03902
# [792]	eval-logloss:0.03901
# [793]	eval-logloss:0.03901
# [794]	eval-logloss:0.03901
# [795]	eval-logloss:0.03901
# [796]	eval-logloss:0.03901
# [797]	eval-logloss:0.03901
# [798]	eval-logloss:0.03901
# [799]	eval-logloss:0.03901
# [800]	eval-logloss:0.03901
# [801]	eval-logloss:0.03901
# [802]	eval-logloss:0.03901
# [803]	eval-logloss:0.03901
# [804]	eval-logloss:0.03901
# [805]	eval-logloss:0.03901
# [806]	eval-logloss:0.03900
# [807]	eval-logloss:0.03900
# [808]	eval-logloss:0.03900
# [809]	eval-logloss:0.03900
# [810]	eval-logloss:0.03900
# [811]	eval-logloss:0.03900
# [812]	eval-logloss:0.03900
# [813]	eval-logloss:0.03899
# [814]	eval-logloss:0.03899
# [815]	eval-logloss:0.03899
# [816]	eval-logloss:0.03899
# [817]	eval-logloss:0.03899
# [818]	eval-logloss:0.03899
# [819]	eval-logloss:0.03899
# [820]	eval-logloss:0.03899
# [821]	eval-logloss:0.03898
# [822]	eval-logloss:0.03898
# [823]	eval-logloss:0.03898
# [824]	eval-logloss:0.03898
# [825]	eval-logloss:0.03898
# [826]	eval-logloss:0.03898
# [827]	eval-logloss:0.03897
# [828]	eval-logloss:0.03897
# [829]	eval-logloss:0.03897
# [830]	eval-logloss:0.03897
# [831]	eval-logloss:0.03897
# [832]	eval-logloss:0.03897
# [833]	eval-logloss:0.03897
# [834]	eval-logloss:0.03897
# [835]	eval-logloss:0.03897
# [836]	eval-logloss:0.03898
# [837]	eval-logloss:0.03897
# [838]	eval-logloss:0.03897
# [839]	eval-logloss:0.03897
# [840]	eval-logloss:0.03897
# [841]	eval-logloss:0.03897
# [842]	eval-logloss:0.03896
# [843]	eval-logloss:0.03897
# [844]	eval-logloss:0.03896
# [845]	eval-logloss:0.03896
# [846]	eval-logloss:0.03896
# [847]	eval-logloss:0.03895
# [848]	eval-logloss:0.03895
# [849]	eval-logloss:0.03895
# [850]	eval-logloss:0.03895
# [851]	eval-logloss:0.03895
# [852]	eval-logloss:0.03895
# [853]	eval-logloss:0.03895
# [854]	eval-logloss:0.03896
# [855]	eval-logloss:0.03895
# [856]	eval-logloss:0.03895
# [857]	eval-logloss:0.03895
# [858]	eval-logloss:0.03895
# [859]	eval-logloss:0.03895
# [860]	eval-logloss:0.03895
# [861]	eval-logloss:0.03894
# [862]	eval-logloss:0.03894
# [863]	eval-logloss:0.03894
# [864]	eval-logloss:0.03895
# [865]	eval-logloss:0.03895
# [866]	eval-logloss:0.03895
# [867]	eval-logloss:0.03894
# [868]	eval-logloss:0.03894
# [869]	eval-logloss:0.03894
# [870]	eval-logloss:0.03895
# [871]	eval-logloss:0.03895
# [872]	eval-logloss:0.03895
# [873]	eval-logloss:0.03895
# [874]	eval-logloss:0.03896
# [875]	eval-logloss:0.03896
# [876]	eval-logloss:0.03897
# [877]	eval-logloss:0.03897
# [878]	eval-logloss:0.03896
# [879]	eval-logloss:0.03896
# [880]	eval-logloss:0.03896
# [881]	eval-logloss:0.03896
# [882]	eval-logloss:0.03897
# [883]	eval-logloss:0.03897
# [884]	eval-logloss:0.03896
# [885]	eval-logloss:0.03896
# [886]	eval-logloss:0.03896
# [887]	eval-logloss:0.03896
# [888]	eval-logloss:0.03896
# [889]	eval-logloss:0.03896
# [890]	eval-logloss:0.03896
# [891]	eval-logloss:0.03896
# [892]	eval-logloss:0.03896
# [893]	eval-logloss:0.03896
# [894]	eval-logloss:0.03896
# [895]	eval-logloss:0.03896
# [896]	eval-logloss:0.03895
# [897]	eval-logloss:0.03895
# [898]	eval-logloss:0.03895
# [899]	eval-logloss:0.03895
# [900]	eval-logloss:0.03895
# [901]	eval-logloss:0.03895
# [902]	eval-logloss:0.03895
# [903]	eval-logloss:0.03895
# [904]	eval-logloss:0.03895
# [905]	eval-logloss:0.03895
# [906]	eval-logloss:0.03895
# [907]	eval-logloss:0.03895
# [908]	eval-logloss:0.03895
# [909]	eval-logloss:0.03895
# [910]	eval-logloss:0.03895
# [911]	eval-logloss:0.03895
# [912]	eval-logloss:0.03895
# [913]	eval-logloss:0.03895
# [914]	eval-logloss:0.03895
# [915]	eval-logloss:0.03895
# [916]	eval-logloss:0.03895
# [917]	eval-logloss:0.03895
# [918]	eval-logloss:0.03894
# [919]	eval-logloss:0.03895
# [920]	eval-logloss:0.03894
# [921]	eval-logloss:0.03894
# [922]	eval-logloss:0.03895
# [923]	eval-logloss:0.03894
# [924]	eval-logloss:0.03894
# [925]	eval-logloss:0.03894
# [926]	eval-logloss:0.03894
# [927]	eval-logloss:0.03895
# [928]	eval-logloss:0.03895
# [929]	eval-logloss:0.03895
# [930]	eval-logloss:0.03895
# [931]	eval-logloss:0.03895
# [932]	eval-logloss:0.03895
# [933]	eval-logloss:0.03895
# [934]	eval-logloss:0.03895
# [935]	eval-logloss:0.03895
# [936]	eval-logloss:0.03895
# [937]	eval-logloss:0.03895
# [938]	eval-logloss:0.03894
# [939]	eval-logloss:0.03895
# [940]	eval-logloss:0.03895
# [941]	eval-logloss:0.03894
# [942]	eval-logloss:0.03895
# [943]	eval-logloss:0.03894
# [944]	eval-logloss:0.03894
# [945]	eval-logloss:0.03894
# [946]	eval-logloss:0.03894
# [947]	eval-logloss:0.03894
# [948]	eval-logloss:0.03894
# [949]	eval-logloss:0.03894
# [950]	eval-logloss:0.03893
# [951]	eval-logloss:0.03893
# [952]	eval-logloss:0.03893
# [953]	eval-logloss:0.03893
# [954]	eval-logloss:0.03893
# [955]	eval-logloss:0.03893
# [956]	eval-logloss:0.03893
# [957]	eval-logloss:0.03892
# [958]	eval-logloss:0.03892
# [959]	eval-logloss:0.03892
# [960]	eval-logloss:0.03892
# [961]	eval-logloss:0.03892
# [962]	eval-logloss:0.03892
# [963]	eval-logloss:0.03892
# [964]	eval-logloss:0.03892
# [965]	eval-logloss:0.03893
# [966]	eval-logloss:0.03893
# [967]	eval-logloss:0.03893
# [968]	eval-logloss:0.03893
# [969]	eval-logloss:0.03893
# [970]	eval-logloss:0.03893
# [971]	eval-logloss:0.03893
# [972]	eval-logloss:0.03893
# [973]	eval-logloss:0.03893
# [974]	eval-logloss:0.03893
# [975]	eval-logloss:0.03893
# [976]	eval-logloss:0.03893
# [977]	eval-logloss:0.03893
# [978]	eval-logloss:0.03893
# [979]	eval-logloss:0.03893
# [980]	eval-logloss:0.03893
# [981]	eval-logloss:0.03893
# [982]	eval-logloss:0.03893
# [983]	eval-logloss:0.03893
# [984]	eval-logloss:0.03894
# [985]	eval-logloss:0.03894
# [986]	eval-logloss:0.03894
# [987]	eval-logloss:0.03894
# [988]	eval-logloss:0.03893
# [989]	eval-logloss:0.03894
# [990]	eval-logloss:0.03894
# [991]	eval-logloss:0.03894
# [992]	eval-logloss:0.03894
# [993]	eval-logloss:0.03894
# [994]	eval-logloss:0.03894
# [995]	eval-logloss:0.03894
# [996]	eval-logloss:0.03894
# [997]	eval-logloss:0.03894
# [998]	eval-logloss:0.03894
# [999]	eval-logloss:0.03894
# [1000]	eval-logloss:0.03893
# [1001]	eval-logloss:0.03893
# [1002]	eval-logloss:0.03893
# [1003]	eval-logloss:0.03893
# [1004]	eval-logloss:0.03893
# [1005]	eval-logloss:0.03894
# [1006]	eval-logloss:0.03894
# [1007]	eval-logloss:0.03893
# [1008]	eval-logloss:0.03893
# [1009]	eval-logloss:0.03893
# [1010]	eval-logloss:0.03893
# [1011]	eval-logloss:0.03892
# [1012]	eval-logloss:0.03892
# [1013]	eval-logloss:0.03892
# [1014]	eval-logloss:0.03892
# [1015]	eval-logloss:0.03892
# [1016]	eval-logloss:0.03892
# [1017]	eval-logloss:0.03892
# [1018]	eval-logloss:0.03892
# [1019]	eval-logloss:0.03892
# [1020]	eval-logloss:0.03892
# [1021]	eval-logloss:0.03892
# [1022]	eval-logloss:0.03892
# [1023]	eval-logloss:0.03892
# [1024]	eval-logloss:0.03892
# [1025]	eval-logloss:0.03892
# [1026]	eval-logloss:0.03892
# [1027]	eval-logloss:0.03892
# [1028]	eval-logloss:0.03892
# [1029]	eval-logloss:0.03892
# [1030]	eval-logloss:0.03892
# [1031]	eval-logloss:0.03892
# [1032]	eval-logloss:0.03892
# [1033]	eval-logloss:0.03892
# [1034]	eval-logloss:0.03892
# [1035]	eval-logloss:0.03892
# [1036]	eval-logloss:0.03892
# [1037]	eval-logloss:0.03892
# [1038]	eval-logloss:0.03892
# [1039]	eval-logloss:0.03892
# [1040]	eval-logloss:0.03893
# [1041]	eval-logloss:0.03892
# [1042]	eval-logloss:0.03892
# [1043]	eval-logloss:0.03893
# [1044]	eval-logloss:0.03893
# [1045]	eval-logloss:0.03892
# [1046]	eval-logloss:0.03891
# [1047]	eval-logloss:0.03891
# [1048]	eval-logloss:0.03892
# [1049]	eval-logloss:0.03892
# [1050]	eval-logloss:0.03892
# [1051]	eval-logloss:0.03892
# [1052]	eval-logloss:0.03892
# [1053]	eval-logloss:0.03891
# [1054]	eval-logloss:0.03891
# [1055]	eval-logloss:0.03891
# [1056]	eval-logloss:0.03891
# [1057]	eval-logloss:0.03891
# [1058]	eval-logloss:0.03891
# [1059]	eval-logloss:0.03892
# [1060]	eval-logloss:0.03891
# [1061]	eval-logloss:0.03892
# [1062]	eval-logloss:0.03892
# [1063]	eval-logloss:0.03891
# [1064]	eval-logloss:0.03891
# [1065]	eval-logloss:0.03891
# [1066]	eval-logloss:0.03891
# [1067]	eval-logloss:0.03891
# [1068]	eval-logloss:0.03891
# [1069]	eval-logloss:0.03890
# [1070]	eval-logloss:0.03890
# [1071]	eval-logloss:0.03890
# [1072]	eval-logloss:0.03890
# [1073]	eval-logloss:0.03890
# [1074]	eval-logloss:0.03890
# [1075]	eval-logloss:0.03890
# [1076]	eval-logloss:0.03890
# [1077]	eval-logloss:0.03889
# [1078]	eval-logloss:0.03889
# [1079]	eval-logloss:0.03889
# [1080]	eval-logloss:0.03889
# [1081]	eval-logloss:0.03889
# [1082]	eval-logloss:0.03889
# [1083]	eval-logloss:0.03889
# [1084]	eval-logloss:0.03889
# [1085]	eval-logloss:0.03889
# [1086]	eval-logloss:0.03889
# [1087]	eval-logloss:0.03889
# [1088]	eval-logloss:0.03888
# [1089]	eval-logloss:0.03888
# [1090]	eval-logloss:0.03888
# [1091]	eval-logloss:0.03888
# [1092]	eval-logloss:0.03888
# [1093]	eval-logloss:0.03888
# [1094]	eval-logloss:0.03888
# [1095]	eval-logloss:0.03888
# [1096]	eval-logloss:0.03888
# [1097]	eval-logloss:0.03888
# [1098]	eval-logloss:0.03888
# [1099]	eval-logloss:0.03888
# [1100]	eval-logloss:0.03888
# [1101]	eval-logloss:0.03888
# [1102]	eval-logloss:0.03889
# [1103]	eval-logloss:0.03889
# [1104]	eval-logloss:0.03889
# [1105]	eval-logloss:0.03889
# [1106]	eval-logloss:0.03889
# [1107]	eval-logloss:0.03889
# [1108]	eval-logloss:0.03889
# [1109]	eval-logloss:0.03889
# [1110]	eval-logloss:0.03890
# [1111]	eval-logloss:0.03889
# [1112]	eval-logloss:0.03889
# [1113]	eval-logloss:0.03889
# [1114]	eval-logloss:0.03888
# [1115]	eval-logloss:0.03889
# [1116]	eval-logloss:0.03889
# [1117]	eval-logloss:0.03889
# [1118]	eval-logloss:0.03889
# [1119]	eval-logloss:0.03889
# [1120]	eval-logloss:0.03889
# [1121]	eval-logloss:0.03889
# [1122]	eval-logloss:0.03889
# [1123]	eval-logloss:0.03889
# [1124]	eval-logloss:0.03888
# [1125]	eval-logloss:0.03888
# [1126]	eval-logloss:0.03888
# [1127]	eval-logloss:0.03888
# [1128]	eval-logloss:0.03888
# [1129]	eval-logloss:0.03888
# [1130]	eval-logloss:0.03888
# [1131]	eval-logloss:0.03888
# [1132]	eval-logloss:0.03889
# [1133]	eval-logloss:0.03889
# [1134]	eval-logloss:0.03889
# [1135]	eval-logloss:0.03889
# [1136]	eval-logloss:0.03889
# [1137]	eval-logloss:0.03889
# [1138]	eval-logloss:0.03889
# [1139]	eval-logloss:0.03889
# [1140]	eval-logloss:0.03889
# [1141]	eval-logloss:0.03889
# [1142]	eval-logloss:0.03889
# [1143]	eval-logloss:0.03889
# [1144]	eval-logloss:0.03889
# [1145]	eval-logloss:0.03889
# [1146]	eval-logloss:0.03888
# [1147]	eval-logloss:0.03889
# [1148]	eval-logloss:0.03889
# [1149]	eval-logloss:0.03889
# [1150]	eval-logloss:0.03889
# [1151]	eval-logloss:0.03889
# [1152]	eval-logloss:0.03889
# [1153]	eval-logloss:0.03889
# [1154]	eval-logloss:0.03889
# [1155]	eval-logloss:0.03892
# [1156]	eval-logloss:0.03892
# [1157]	eval-logloss:0.03892
# [1158]	eval-logloss:0.03892
# [1159]	eval-logloss:0.03892
# [1160]	eval-logloss:0.03893
# [1161]	eval-logloss:0.03893
# [1162]	eval-logloss:0.03893
# [1163]	eval-logloss:0.03893
# [1164]	eval-logloss:0.03893
# [1165]	eval-logloss:0.03893
# [1166]	eval-logloss:0.03893
# [1167]	eval-logloss:0.03893
# [1168]	eval-logloss:0.03894
# [1169]	eval-logloss:0.03894
# [1170]	eval-logloss:0.03894
# [1171]	eval-logloss:0.03894
# [1172]	eval-logloss:0.03894
# [1173]	eval-logloss:0.03894
# [1174]	eval-logloss:0.03894
# [1175]	eval-logloss:0.03894
# [1176]	eval-logloss:0.03894
# [1177]	eval-logloss:0.03894
# [1178]	eval-logloss:0.03894
# [1179]	eval-logloss:0.03894
# [1180]	eval-logloss:0.03894
# [1181]	eval-logloss:0.03894
# [1182]	eval-logloss:0.03893
# [1183]	eval-logloss:0.03893
# [1184]	eval-logloss:0.03893
# [1185]	eval-logloss:0.03894
# [1186]	eval-logloss:0.03894
# [1187]	eval-logloss:0.03894
# [1188]	eval-logloss:0.03894
# [1189]	eval-logloss:0.03894
# [1190]	eval-logloss:0.03894
# [1191]	eval-logloss:0.03894
# [1192]	eval-logloss:0.03894
# [1193]	eval-logloss:0.03893
# [1194]	eval-logloss:0.03894
# [1195]	eval-logloss:0.03894
# [1196]	eval-logloss:0.03894
# [1197]	eval-logloss:0.03894
# [1198]	eval-logloss:0.03894
# [1199]	eval-logloss:0.03894
# [1200]	eval-logloss:0.03894
# [0]	eval-logloss:0.64064
# [1]	eval-logloss:0.60391
# [2]	eval-logloss:0.56422
# [3]	eval-logloss:0.53437
# [4]	eval-logloss:0.50180
# [5]	eval-logloss:0.47399
# [6]	eval-logloss:0.44095
# [7]	eval-logloss:0.41459
# [8]	eval-logloss:0.39428
# [9]	eval-logloss:0.37746
# [10]	eval-logloss:0.35645
# [11]	eval-logloss:0.33976
# [12]	eval-logloss:0.32167
# [13]	eval-logloss:0.31032
# [14]	eval-logloss:0.29489
# [15]	eval-logloss:0.28499
# [16]	eval-logloss:0.27376
# [17]	eval-logloss:0.26422
# [18]	eval-logloss:0.25665
# [19]	eval-logloss:0.24750
# [20]	eval-logloss:0.24103
# [21]	eval-logloss:0.23355
# [22]	eval-logloss:0.22691
# [23]	eval-logloss:0.22174
# [24]	eval-logloss:0.21587
# [25]	eval-logloss:0.21119
# [26]	eval-logloss:0.20624
# [27]	eval-logloss:0.20254
# [28]	eval-logloss:0.19363
# [29]	eval-logloss:0.19066
# [30]	eval-logloss:0.18543
# [31]	eval-logloss:0.18055
# [32]	eval-logloss:0.17790
# [33]	eval-logloss:0.17486
# [34]	eval-logloss:0.17027
# [35]	eval-logloss:0.16554
# [36]	eval-logloss:0.16296
# [37]	eval-logloss:0.16124
# [38]	eval-logloss:0.15883
# [39]	eval-logloss:0.15502
# [40]	eval-logloss:0.15275
# [41]	eval-logloss:0.15143
# [42]	eval-logloss:0.14583
# [43]	eval-logloss:0.14229
# [44]	eval-logloss:0.14023
# [45]	eval-logloss:0.13833
# [46]	eval-logloss:0.13623
# [47]	eval-logloss:0.13243
# [48]	eval-logloss:0.13061
# [49]	eval-logloss:0.12956
# [50]	eval-logloss:0.12791
# [51]	eval-logloss:0.12562
# [52]	eval-logloss:0.12363
# [53]	eval-logloss:0.11937
# [54]	eval-logloss:0.11747
# [55]	eval-logloss:0.11583
# [56]	eval-logloss:0.11511
# [57]	eval-logloss:0.11397
# [58]	eval-logloss:0.11312
# [59]	eval-logloss:0.11177
# [60]	eval-logloss:0.11007
# [61]	eval-logloss:0.10875
# [62]	eval-logloss:0.10718
# [63]	eval-logloss:0.10548
# [64]	eval-logloss:0.10438
# [65]	eval-logloss:0.10336
# [66]	eval-logloss:0.10261
# [67]	eval-logloss:0.10200
# [68]	eval-logloss:0.10098
# [69]	eval-logloss:0.10063
# [70]	eval-logloss:0.10016
# [71]	eval-logloss:0.09822
# [72]	eval-logloss:0.09781
# [73]	eval-logloss:0.09639
# [74]	eval-logloss:0.09489
# [75]	eval-logloss:0.09319
# [76]	eval-logloss:0.09216
# [77]	eval-logloss:0.09160
# [78]	eval-logloss:0.08988
# [79]	eval-logloss:0.08902
# [80]	eval-logloss:0.08770
# [81]	eval-logloss:0.08696
# [82]	eval-logloss:0.08619
# [83]	eval-logloss:0.08562
# [84]	eval-logloss:0.08504
# [85]	eval-logloss:0.08391
# [86]	eval-logloss:0.08332
# [87]	eval-logloss:0.08278
# [88]	eval-logloss:0.08251
# [89]	eval-logloss:0.08131
# [90]	eval-logloss:0.08046
# [91]	eval-logloss:0.08014
# [92]	eval-logloss:0.07965
# [93]	eval-logloss:0.07867
# [94]	eval-logloss:0.07755
# [95]	eval-logloss:0.07679
# [96]	eval-logloss:0.07658
# [97]	eval-logloss:0.07506
# [98]	eval-logloss:0.07432
# [99]	eval-logloss:0.07371
# [100]	eval-logloss:0.07339
# [101]	eval-logloss:0.07254
# [102]	eval-logloss:0.07176
# [103]	eval-logloss:0.07127
# [104]	eval-logloss:0.07100
# [105]	eval-logloss:0.07069
# [106]	eval-logloss:0.07029
# [107]	eval-logloss:0.07004
# [108]	eval-logloss:0.06954
# [109]	eval-logloss:0.06907
# [110]	eval-logloss:0.06841
# [111]	eval-logloss:0.06765
# [112]	eval-logloss:0.06727
# [113]	eval-logloss:0.06714
# [114]	eval-logloss:0.06658
# [115]	eval-logloss:0.06586
# [116]	eval-logloss:0.06523
# [117]	eval-logloss:0.06493
# [118]	eval-logloss:0.06474
# [119]	eval-logloss:0.06436
# [120]	eval-logloss:0.06386
# [121]	eval-logloss:0.06352
# [122]	eval-logloss:0.06332
# [123]	eval-logloss:0.06270
# [124]	eval-logloss:0.06233
# [125]	eval-logloss:0.06201
# [126]	eval-logloss:0.06170
# [127]	eval-logloss:0.06135
# [128]	eval-logloss:0.06092
# [129]	eval-logloss:0.06086
# [130]	eval-logloss:0.06030
# [131]	eval-logloss:0.06002
# [132]	eval-logloss:0.05966
# [133]	eval-logloss:0.05930
# [134]	eval-logloss:0.05879
# [135]	eval-logloss:0.05867
# [136]	eval-logloss:0.05829
# [137]	eval-logloss:0.05817
# [138]	eval-logloss:0.05777
# [139]	eval-logloss:0.05759
# [140]	eval-logloss:0.05722
# [141]	eval-logloss:0.05695
# [142]	eval-logloss:0.05675
# [143]	eval-logloss:0.05658
# [144]	eval-logloss:0.05648
# [145]	eval-logloss:0.05630
# [146]	eval-logloss:0.05583
# [147]	eval-logloss:0.05546
# [148]	eval-logloss:0.05541
# [149]	eval-logloss:0.05527
# [150]	eval-logloss:0.05496
# [151]	eval-logloss:0.05468
# [152]	eval-logloss:0.05441
# [153]	eval-logloss:0.05429
# [154]	eval-logloss:0.05418
# [155]	eval-logloss:0.05397
# [156]	eval-logloss:0.05366
# [157]	eval-logloss:0.05308
# [158]	eval-logloss:0.05283
# [159]	eval-logloss:0.05241
# [160]	eval-logloss:0.05224
# [161]	eval-logloss:0.05211
# [162]	eval-logloss:0.05178
# [163]	eval-logloss:0.05167
# [164]	eval-logloss:0.05153
# [165]	eval-logloss:0.05137
# [166]	eval-logloss:0.05127
# [167]	eval-logloss:0.05107
# [168]	eval-logloss:0.05051
# [169]	eval-logloss:0.05004
# [170]	eval-logloss:0.04987
# [171]	eval-logloss:0.04980
# [172]	eval-logloss:0.04973
# [173]	eval-logloss:0.04934
# [174]	eval-logloss:0.04923
# [175]	eval-logloss:0.04916
# [176]	eval-logloss:0.04902
# [177]	eval-logloss:0.04886
# [178]	eval-logloss:0.04871
# [179]	eval-logloss:0.04851
# [180]	eval-logloss:0.04826
# [181]	eval-logloss:0.04822
# [182]	eval-logloss:0.04813
# [183]	eval-logloss:0.04794
# [184]	eval-logloss:0.04770
# [185]	eval-logloss:0.04755
# [186]	eval-logloss:0.04742
# [187]	eval-logloss:0.04719
# [188]	eval-logloss:0.04713
# [189]	eval-logloss:0.04703
# [190]	eval-logloss:0.04699
# [191]	eval-logloss:0.04685
# [192]	eval-logloss:0.04676
# [193]	eval-logloss:0.04673
# [194]	eval-logloss:0.04665
# [195]	eval-logloss:0.04660
# [196]	eval-logloss:0.04653
# [197]	eval-logloss:0.04629
# [198]	eval-logloss:0.04615
# [199]	eval-logloss:0.04612
# [200]	eval-logloss:0.04599
# [201]	eval-logloss:0.04587
# [202]	eval-logloss:0.04578
# [203]	eval-logloss:0.04572
# [204]	eval-logloss:0.04562
# [205]	eval-logloss:0.04558
# [206]	eval-logloss:0.04544
# [207]	eval-logloss:0.04531
# [208]	eval-logloss:0.04524
# [209]	eval-logloss:0.04520
# [210]	eval-logloss:0.04516
# [211]	eval-logloss:0.04502
# [212]	eval-logloss:0.04497
# [213]	eval-logloss:0.04489
# [214]	eval-logloss:0.04484
# [215]	eval-logloss:0.04480
# [216]	eval-logloss:0.04471
# [217]	eval-logloss:0.04465
# [218]	eval-logloss:0.04463
# [219]	eval-logloss:0.04459
# [220]	eval-logloss:0.04448
# [221]	eval-logloss:0.04438
# [222]	eval-logloss:0.04434
# [223]	eval-logloss:0.04431
# [224]	eval-logloss:0.04429
# [225]	eval-logloss:0.04427
# [226]	eval-logloss:0.04420
# [227]	eval-logloss:0.04414
# [228]	eval-logloss:0.04413
# [229]	eval-logloss:0.04411
# [230]	eval-logloss:0.04407
# [231]	eval-logloss:0.04400
# [232]	eval-logloss:0.04391
# [233]	eval-logloss:0.04386
# [234]	eval-logloss:0.04379
# [235]	eval-logloss:0.04374
# [236]	eval-logloss:0.04363
# [237]	eval-logloss:0.04359
# [238]	eval-logloss:0.04355
# [239]	eval-logloss:0.04353
# [240]	eval-logloss:0.04349
# [241]	eval-logloss:0.04337
# [242]	eval-logloss:0.04331
# [243]	eval-logloss:0.04323
# [244]	eval-logloss:0.04315
# [245]	eval-logloss:0.04313
# [246]	eval-logloss:0.04306
# [247]	eval-logloss:0.04295
# [248]	eval-logloss:0.04287
# [249]	eval-logloss:0.04280
# [250]	eval-logloss:0.04274
# [251]	eval-logloss:0.04263
# [252]	eval-logloss:0.04259
# [253]	eval-logloss:0.04257
# [254]	eval-logloss:0.04252
# [255]	eval-logloss:0.04243
# [256]	eval-logloss:0.04242
# [257]	eval-logloss:0.04238
# [258]	eval-logloss:0.04234
# [259]	eval-logloss:0.04231
# [260]	eval-logloss:0.04227
# [261]	eval-logloss:0.04223
# [262]	eval-logloss:0.04217
# [263]	eval-logloss:0.04215
# [264]	eval-logloss:0.04213
# [265]	eval-logloss:0.04207
# [266]	eval-logloss:0.04203
# [267]	eval-logloss:0.04200
# [268]	eval-logloss:0.04199
# [269]	eval-logloss:0.04197
# [270]	eval-logloss:0.04194
# [271]	eval-logloss:0.04190
# [272]	eval-logloss:0.04187
# [273]	eval-logloss:0.04186
# [274]	eval-logloss:0.04185
# [275]	eval-logloss:0.04180
# [276]	eval-logloss:0.04175
# [277]	eval-logloss:0.04172
# [278]	eval-logloss:0.04168
# [279]	eval-logloss:0.04164
# [280]	eval-logloss:0.04161
# [281]	eval-logloss:0.04158
# [282]	eval-logloss:0.04156
# [283]	eval-logloss:0.04154
# [284]	eval-logloss:0.04152
# [285]	eval-logloss:0.04151
# [286]	eval-logloss:0.04149
# [287]	eval-logloss:0.04147
# [288]	eval-logloss:0.04146
# [289]	eval-logloss:0.04144
# [290]	eval-logloss:0.04141
# [291]	eval-logloss:0.04140
# [292]	eval-logloss:0.04137
# [293]	eval-logloss:0.04133
# [294]	eval-logloss:0.04130
# [295]	eval-logloss:0.04127
# [296]	eval-logloss:0.04124
# [297]	eval-logloss:0.04124
# [298]	eval-logloss:0.04123
# [299]	eval-logloss:0.04122
# [300]	eval-logloss:0.04120
# [301]	eval-logloss:0.04117
# [302]	eval-logloss:0.04113
# [303]	eval-logloss:0.04110
# [304]	eval-logloss:0.04110
# [305]	eval-logloss:0.04109
# [306]	eval-logloss:0.04105
# [307]	eval-logloss:0.04102
# [308]	eval-logloss:0.04101
# [309]	eval-logloss:0.04099
# [310]	eval-logloss:0.04096
# [311]	eval-logloss:0.04093
# [312]	eval-logloss:0.04092
# [313]	eval-logloss:0.04090
# [314]	eval-logloss:0.04087
# [315]	eval-logloss:0.04085
# [316]	eval-logloss:0.04083
# [317]	eval-logloss:0.04082
# [318]	eval-logloss:0.04081
# [319]	eval-logloss:0.04078
# [320]	eval-logloss:0.04077
# [321]	eval-logloss:0.04075
# [322]	eval-logloss:0.04072
# [323]	eval-logloss:0.04070
# [324]	eval-logloss:0.04068
# [325]	eval-logloss:0.04068
# [326]	eval-logloss:0.04067
# [327]	eval-logloss:0.04065
# [328]	eval-logloss:0.04063
# [329]	eval-logloss:0.04060
# [330]	eval-logloss:0.04059
# [331]	eval-logloss:0.04057
# [332]	eval-logloss:0.04056
# [333]	eval-logloss:0.04055
# [334]	eval-logloss:0.04053
# [335]	eval-logloss:0.04051
# [336]	eval-logloss:0.04050
# [337]	eval-logloss:0.04049
# [338]	eval-logloss:0.04047
# [339]	eval-logloss:0.04046
# [340]	eval-logloss:0.04044
# [341]	eval-logloss:0.04043
# [342]	eval-logloss:0.04042
# [343]	eval-logloss:0.04041
# [344]	eval-logloss:0.04040
# [345]	eval-logloss:0.04037
# [346]	eval-logloss:0.04037
# [347]	eval-logloss:0.04035
# [348]	eval-logloss:0.04034
# [349]	eval-logloss:0.04032
# [350]	eval-logloss:0.04031
# [351]	eval-logloss:0.04030
# [352]	eval-logloss:0.04029
# [353]	eval-logloss:0.04027
# [354]	eval-logloss:0.04027
# [355]	eval-logloss:0.04026
# [356]	eval-logloss:0.04024
# [357]	eval-logloss:0.04024
# [358]	eval-logloss:0.04021
# [359]	eval-logloss:0.04020
# [360]	eval-logloss:0.04018
# [361]	eval-logloss:0.04017
# [362]	eval-logloss:0.04017
# [363]	eval-logloss:0.04016
# [364]	eval-logloss:0.04015
# [365]	eval-logloss:0.04014
# [366]	eval-logloss:0.04012
# [367]	eval-logloss:0.04012
# [368]	eval-logloss:0.04010
# [369]	eval-logloss:0.04009
# [370]	eval-logloss:0.04009
# [371]	eval-logloss:0.04007
# [372]	eval-logloss:0.04007
# [373]	eval-logloss:0.04006
# [374]	eval-logloss:0.04006
# [375]	eval-logloss:0.04005
# [376]	eval-logloss:0.04004
# [377]	eval-logloss:0.04004
# [378]	eval-logloss:0.04003
# [379]	eval-logloss:0.04002
# [380]	eval-logloss:0.04001
# [381]	eval-logloss:0.04000
# [382]	eval-logloss:0.03999
# [383]	eval-logloss:0.03998
# [384]	eval-logloss:0.03996
# [385]	eval-logloss:0.03995
# [386]	eval-logloss:0.03994
# [387]	eval-logloss:0.03993
# [388]	eval-logloss:0.03992
# [389]	eval-logloss:0.03992
# [390]	eval-logloss:0.03991
# [391]	eval-logloss:0.03991
# [392]	eval-logloss:0.03991
# [393]	eval-logloss:0.03990
# [394]	eval-logloss:0.03989
# [395]	eval-logloss:0.03989
# [396]	eval-logloss:0.03988
# [397]	eval-logloss:0.03987
# [398]	eval-logloss:0.03986
# [399]	eval-logloss:0.03985
# [400]	eval-logloss:0.03984
# [401]	eval-logloss:0.03982
# [402]	eval-logloss:0.03982
# [403]	eval-logloss:0.03981
# [404]	eval-logloss:0.03980
# [405]	eval-logloss:0.03980
# [406]	eval-logloss:0.03980
# [407]	eval-logloss:0.03979
# [408]	eval-logloss:0.03978
# [409]	eval-logloss:0.03977
# [410]	eval-logloss:0.03977
# [411]	eval-logloss:0.03975
# [412]	eval-logloss:0.03974
# [413]	eval-logloss:0.03973
# [414]	eval-logloss:0.03972
# [415]	eval-logloss:0.03971
# [416]	eval-logloss:0.03971
# [417]	eval-logloss:0.03970
# [418]	eval-logloss:0.03969
# [419]	eval-logloss:0.03969
# [420]	eval-logloss:0.03968
# [421]	eval-logloss:0.03968
# [422]	eval-logloss:0.03968
# [423]	eval-logloss:0.03967
# [424]	eval-logloss:0.03967
# [425]	eval-logloss:0.03966
# [426]	eval-logloss:0.03966
# [427]	eval-logloss:0.03966
# [428]	eval-logloss:0.03965
# [429]	eval-logloss:0.03964
# [430]	eval-logloss:0.03963
# [431]	eval-logloss:0.03963
# [432]	eval-logloss:0.03962
# [433]	eval-logloss:0.03961
# [434]	eval-logloss:0.03961
# [435]	eval-logloss:0.03960
# [436]	eval-logloss:0.03959
# [437]	eval-logloss:0.03959
# [438]	eval-logloss:0.03959
# [439]	eval-logloss:0.03959
# [440]	eval-logloss:0.03958
# [441]	eval-logloss:0.03957
# [442]	eval-logloss:0.03956
# [443]	eval-logloss:0.03956
# [444]	eval-logloss:0.03955
# [445]	eval-logloss:0.03955
# [446]	eval-logloss:0.03955
# [447]	eval-logloss:0.03954
# [448]	eval-logloss:0.03954
# [449]	eval-logloss:0.03953
# [450]	eval-logloss:0.03953
# [451]	eval-logloss:0.03952
# [452]	eval-logloss:0.03951
# [453]	eval-logloss:0.03950
# [454]	eval-logloss:0.03951
# [455]	eval-logloss:0.03950
# [456]	eval-logloss:0.03949
# [457]	eval-logloss:0.03949
# [458]	eval-logloss:0.03948
# [459]	eval-logloss:0.03947
# [460]	eval-logloss:0.03947
# [461]	eval-logloss:0.03947
# [462]	eval-logloss:0.03947
# [463]	eval-logloss:0.03946
# [464]	eval-logloss:0.03946
# [465]	eval-logloss:0.03946
# [466]	eval-logloss:0.03945
# [467]	eval-logloss:0.03945
# [468]	eval-logloss:0.03944
# [469]	eval-logloss:0.03944
# [470]	eval-logloss:0.03943
# [471]	eval-logloss:0.03942
# [472]	eval-logloss:0.03941
# [473]	eval-logloss:0.03941
# [474]	eval-logloss:0.03940
# [475]	eval-logloss:0.03940
# [476]	eval-logloss:0.03939
# [477]	eval-logloss:0.03939
# [478]	eval-logloss:0.03939
# [479]	eval-logloss:0.03939
# [480]	eval-logloss:0.03939
# [481]	eval-logloss:0.03938
# [482]	eval-logloss:0.03937
# [483]	eval-logloss:0.03937
# [484]	eval-logloss:0.03936
# [485]	eval-logloss:0.03936
# [486]	eval-logloss:0.03936
# [487]	eval-logloss:0.03935
# [488]	eval-logloss:0.03935
# [489]	eval-logloss:0.03935
# [490]	eval-logloss:0.03935
# [491]	eval-logloss:0.03934
# [492]	eval-logloss:0.03934
# [493]	eval-logloss:0.03934
# [494]	eval-logloss:0.03933
# [495]	eval-logloss:0.03932
# [496]	eval-logloss:0.03932
# [497]	eval-logloss:0.03932
# [498]	eval-logloss:0.03932
# [499]	eval-logloss:0.03930
# [500]	eval-logloss:0.03929
# [501]	eval-logloss:0.03929
# [502]	eval-logloss:0.03929
# [503]	eval-logloss:0.03929
# [504]	eval-logloss:0.03928
# [505]	eval-logloss:0.03927
# [506]	eval-logloss:0.03927
# [507]	eval-logloss:0.03927
# [508]	eval-logloss:0.03926
# [509]	eval-logloss:0.03926
# [510]	eval-logloss:0.03926
# [511]	eval-logloss:0.03925
# [512]	eval-logloss:0.03925
# [513]	eval-logloss:0.03925
# [514]	eval-logloss:0.03924
# [515]	eval-logloss:0.03924
# [516]	eval-logloss:0.03923
# [517]	eval-logloss:0.03923
# [518]	eval-logloss:0.03922
# [519]	eval-logloss:0.03922
# [520]	eval-logloss:0.03922
# [521]	eval-logloss:0.03921
# [522]	eval-logloss:0.03921
# [523]	eval-logloss:0.03921
# [524]	eval-logloss:0.03921
# [525]	eval-logloss:0.03920
# [526]	eval-logloss:0.03920
# [527]	eval-logloss:0.03920
# [528]	eval-logloss:0.03920
# [529]	eval-logloss:0.03920
# [530]	eval-logloss:0.03919
# [531]	eval-logloss:0.03919
# [532]	eval-logloss:0.03919
# [533]	eval-logloss:0.03919
# [534]	eval-logloss:0.03918
# [535]	eval-logloss:0.03918
# [536]	eval-logloss:0.03918
# [537]	eval-logloss:0.03918
# [538]	eval-logloss:0.03917
# [539]	eval-logloss:0.03917
# [540]	eval-logloss:0.03917
# [541]	eval-logloss:0.03917
# [542]	eval-logloss:0.03917
# [543]	eval-logloss:0.03917
# [544]	eval-logloss:0.03917
# [545]	eval-logloss:0.03917
# [546]	eval-logloss:0.03916
# [547]	eval-logloss:0.03916
# [548]	eval-logloss:0.03916
# [549]	eval-logloss:0.03915
# [550]	eval-logloss:0.03915
# [551]	eval-logloss:0.03915
# [552]	eval-logloss:0.03914
# [553]	eval-logloss:0.03914
# [554]	eval-logloss:0.03914
# [555]	eval-logloss:0.03914
# [556]	eval-logloss:0.03913
# [557]	eval-logloss:0.03913
# [558]	eval-logloss:0.03912
# [559]	eval-logloss:0.03912
# [560]	eval-logloss:0.03911
# [561]	eval-logloss:0.03911
# [562]	eval-logloss:0.03911
# [563]	eval-logloss:0.03911
# [564]	eval-logloss:0.03910
# [565]	eval-logloss:0.03910
# [566]	eval-logloss:0.03911
# [567]	eval-logloss:0.03910
# [568]	eval-logloss:0.03910
# [569]	eval-logloss:0.03910
# [570]	eval-logloss:0.03910
# [571]	eval-logloss:0.03910
# ...
# [1184]	eval-logloss:0.03887
# [1185]	eval-logloss:0.03887
# [1186]	eval-logloss:0.03887
# [1187]	eval-logloss:0.03887
# [0]	eval-logloss:0.64399
# [1]	eval-logloss:0.60757
# [2]	eval-logloss:0.56788
# [3]	eval-logloss:0.53677
# [4]	eval-logloss:0.51068
# [5]	eval-logloss:0.48269
# [6]	eval-logloss:0.45218
# [7]	eval-logloss:0.42999
# [8]	eval-logloss:0.40900
# [9]	eval-logloss:0.38680
# [10]	eval-logloss:0.36215
# [11]	eval-logloss:0.34021
# [12]	eval-logloss:0.32127
# [13]	eval-logloss:0.31005
# [14]	eval-logloss:0.29486
# [15]	eval-logloss:0.28485
# [16]	eval-logloss:0.26989
# [17]	eval-logloss:0.26208
# [18]	eval-logloss:0.25412
# [19]	eval-logloss:0.24612
# [20]	eval-logloss:0.23896
# [21]	eval-logloss:0.23035
# [22]	eval-logloss:0.22489
# [23]	eval-logloss:0.21921
# [24]	eval-logloss:0.21430
# [25]	eval-logloss:0.20865
# [26]	eval-logloss:0.20409
# [27]	eval-logloss:0.19862
# [28]	eval-logloss:0.19154
# [29]	eval-logloss:0.18745
# [30]	eval-logloss:0.18398
# [31]	eval-logloss:0.18051
# [32]	eval-logloss:0.17726
# [33]	eval-logloss:0.17353
# [34]	eval-logloss:0.16979
# [35]	eval-logloss:0.16659
# [36]	eval-logloss:0.16210
# [37]	eval-logloss:0.15946
# [38]	eval-logloss:0.15754
# [39]	eval-logloss:0.15299
# [40]	eval-logloss:0.14956
# [41]	eval-logloss:0.14576
# [42]	eval-logloss:0.14134
# [43]	eval-logloss:0.13840
# [44]	eval-logloss:0.13618
# [45]	eval-logloss:0.13218
# [46]	eval-logloss:0.12922
# [47]	eval-logloss:0.12668
# [48]	eval-logloss:0.12562
# [49]	eval-logloss:0.12374
# [50]	eval-logloss:0.12138
# [51]	eval-logloss:0.11899
# [52]	eval-logloss:0.11736
# [53]	eval-logloss:0.11517
# [54]	eval-logloss:0.11328
# [55]	eval-logloss:0.11226
# [56]	eval-logloss:0.11110
# [57]	eval-logloss:0.10916
# [58]	eval-logloss:0.10747
# [59]	eval-logloss:0.10605
# [60]	eval-logloss:0.10425
# [61]	eval-logloss:0.10368
# [62]	eval-logloss:0.10280
# [63]	eval-logloss:0.09978
# [64]	eval-logloss:0.09923
# [65]	eval-logloss:0.09838
# [66]	eval-logloss:0.09558
# [67]	eval-logloss:0.09494
# [68]	eval-logloss:0.09442
# [69]	eval-logloss:0.09342
# [70]	eval-logloss:0.09238
# [71]	eval-logloss:0.09130
# [72]	eval-logloss:0.09065
# [73]	eval-logloss:0.08877
# [74]	eval-logloss:0.08797
# [75]	eval-logloss:0.08581
# [76]	eval-logloss:0.08529
# [77]	eval-logloss:0.08449
# [78]	eval-logloss:0.08385
# [79]	eval-logloss:0.08307
# [80]	eval-logloss:0.08191
# [81]	eval-logloss:0.08036
# [82]	eval-logloss:0.07990
# [83]	eval-logloss:0.07894
# [84]	eval-logloss:0.07808
# [85]	eval-logloss:0.07755
# [86]	eval-logloss:0.07687
# [87]	eval-logloss:0.07646
# [88]	eval-logloss:0.07624
# [89]	eval-logloss:0.07578
# [90]	eval-logloss:0.07500
# [91]	eval-logloss:0.07411
# [92]	eval-logloss:0.07368
# [93]	eval-logloss:0.07325
# [94]	eval-logloss:0.07279
# [95]	eval-logloss:0.07259
# [96]	eval-logloss:0.07211
# [97]	eval-logloss:0.07135
# [98]	eval-logloss:0.07077
# [99]	eval-logloss:0.07007
# [100]	eval-logloss:0.06982
# [101]	eval-logloss:0.06902
# [102]	eval-logloss:0.06881
# [103]	eval-logloss:0.06793
# [104]	eval-logloss:0.06778
# [105]	eval-logloss:0.06756
# [106]	eval-logloss:0.06732
# [107]	eval-logloss:0.06680
# [108]	eval-logloss:0.06613
# [109]	eval-logloss:0.06565
# [110]	eval-logloss:0.06524
# [111]	eval-logloss:0.06494
# [112]	eval-logloss:0.06436
# [113]	eval-logloss:0.06418
# [114]	eval-logloss:0.06385
# [115]	eval-logloss:0.06370
# [116]	eval-logloss:0.06300
# [117]	eval-logloss:0.06276
# [118]	eval-logloss:0.06218
# [119]	eval-logloss:0.06186
# [120]	eval-logloss:0.06157
# [121]	eval-logloss:0.06145
# [122]	eval-logloss:0.06075
# [123]	eval-logloss:0.06053
# [124]	eval-logloss:0.05997
# [125]	eval-logloss:0.05931
# [126]	eval-logloss:0.05917
# [127]	eval-logloss:0.05888
# [128]	eval-logloss:0.05848
# [129]	eval-logloss:0.05814
# [130]	eval-logloss:0.05754
# [131]	eval-logloss:0.05742
# [132]	eval-logloss:0.05726
# [133]	eval-logloss:0.05713
# [134]	eval-logloss:0.05695
# [135]	eval-logloss:0.05691
# [136]	eval-logloss:0.05665
# [137]	eval-logloss:0.05648
# [138]	eval-logloss:0.05617
# [139]	eval-logloss:0.05604
# [140]	eval-logloss:0.05576
# [141]	eval-logloss:0.05567
# [142]	eval-logloss:0.05549
# [143]	eval-logloss:0.05538
# [144]	eval-logloss:0.05506
# [145]	eval-logloss:0.05488
# [146]	eval-logloss:0.05452
# [147]	eval-logloss:0.05409
# [148]	eval-logloss:0.05398
# [149]	eval-logloss:0.05372
# [150]	eval-logloss:0.05344
# [151]	eval-logloss:0.05283
# [152]	eval-logloss:0.05275
# [153]	eval-logloss:0.05263
# [154]	eval-logloss:0.05238
# [155]	eval-logloss:0.05215
# [156]	eval-logloss:0.05205
# [157]	eval-logloss:0.05165
# [158]	eval-logloss:0.05155
# [159]	eval-logloss:0.05136
# [160]	eval-logloss:0.05128
# [161]	eval-logloss:0.05112
# [162]	eval-logloss:0.05077
# [163]	eval-logloss:0.05069
# [164]	eval-logloss:0.05048
# [165]	eval-logloss:0.05042
# [166]	eval-logloss:0.05023
# [167]	eval-logloss:0.05019
# [168]	eval-logloss:0.05003
# [169]	eval-logloss:0.04974
# [170]	eval-logloss:0.04968
# [171]	eval-logloss:0.04959
# [172]	eval-logloss:0.04946
# [173]	eval-logloss:0.04937
# [174]	eval-logloss:0.04919
# [175]	eval-logloss:0.04913
# [176]	eval-logloss:0.04901
# [177]	eval-logloss:0.04891
# [178]	eval-logloss:0.04877
# [179]	eval-logloss:0.04870
# [180]	eval-logloss:0.04842
# [181]	eval-logloss:0.04838
# [182]	eval-logloss:0.04826
# [183]	eval-logloss:0.04800
# [184]	eval-logloss:0.04784
# [185]	eval-logloss:0.04768
# [186]	eval-logloss:0.04748
# [187]	eval-logloss:0.04734
# [188]	eval-logloss:0.04712
# [189]	eval-logloss:0.04697
# [190]	eval-logloss:0.04679
# [191]	eval-logloss:0.04665
# [192]	eval-logloss:0.04660
# [193]	eval-logloss:0.04657
# [194]	eval-logloss:0.04646
# [195]	eval-logloss:0.04642
# [196]	eval-logloss:0.04637
# [197]	eval-logloss:0.04624
# [198]	eval-logloss:0.04618
# [199]	eval-logloss:0.04610
# [200]	eval-logloss:0.04598
# [201]	eval-logloss:0.04589
# [202]	eval-logloss:0.04583
# [203]	eval-logloss:0.04577
# [204]	eval-logloss:0.04566
# [205]	eval-logloss:0.04554
# [206]	eval-logloss:0.04539
# [207]	eval-logloss:0.04524
# [208]	eval-logloss:0.04512
# [209]	eval-logloss:0.04507
# [210]	eval-logloss:0.04495
# [211]	eval-logloss:0.04489
# [212]	eval-logloss:0.04479
# [213]	eval-logloss:0.04460
# [214]	eval-logloss:0.04448
# [215]	eval-logloss:0.04444
# [216]	eval-logloss:0.04435
# [217]	eval-logloss:0.04432
# [218]	eval-logloss:0.04424
# [219]	eval-logloss:0.04418
# [220]	eval-logloss:0.04409
# [221]	eval-logloss:0.04396
# [222]	eval-logloss:0.04386
# [223]	eval-logloss:0.04379
# [224]	eval-logloss:0.04374
# [225]	eval-logloss:0.04366
# [226]	eval-logloss:0.04357
# [227]	eval-logloss:0.04351
# [228]	eval-logloss:0.04349
# [229]	eval-logloss:0.04344
# [230]	eval-logloss:0.04330
# [231]	eval-logloss:0.04324
# [232]	eval-logloss:0.04318
# [233]	eval-logloss:0.04313
# [234]	eval-logloss:0.04305
# [235]	eval-logloss:0.04296
# [236]	eval-logloss:0.04293
# [237]	eval-logloss:0.04288
# [238]	eval-logloss:0.04282
# [239]	eval-logloss:0.04278
# [240]	eval-logloss:0.04271
# [241]	eval-logloss:0.04268
# [242]	eval-logloss:0.04263
# [243]	eval-logloss:0.04259
# [244]	eval-logloss:0.04252
# [245]	eval-logloss:0.04247
# [246]	eval-logloss:0.04245
# [247]	eval-logloss:0.04240
# [248]	eval-logloss:0.04233
# [249]	eval-logloss:0.04230
# [250]	eval-logloss:0.04226
# [251]	eval-logloss:0.04221
# [252]	eval-logloss:0.04218
# [253]	eval-logloss:0.04212
# [254]	eval-logloss:0.04207
# [255]	eval-logloss:0.04202
# [256]	eval-logloss:0.04197
# [257]	eval-logloss:0.04195
# [258]	eval-logloss:0.04191
# [259]	eval-logloss:0.04190
# [260]	eval-logloss:0.04185
# [261]	eval-logloss:0.04183
# [262]	eval-logloss:0.04178
# [263]	eval-logloss:0.04177
# [264]	eval-logloss:0.04174
# [265]	eval-logloss:0.04173
# [266]	eval-logloss:0.04167
# [267]	eval-logloss:0.04166
# [268]	eval-logloss:0.04163
# [269]	eval-logloss:0.04160
# [270]	eval-logloss:0.04157
# [271]	eval-logloss:0.04154
# [272]	eval-logloss:0.04153
# [273]	eval-logloss:0.04151
# [274]	eval-logloss:0.04149
# [275]	eval-logloss:0.04146
# [276]	eval-logloss:0.04144
# [277]	eval-logloss:0.04142
# [278]	eval-logloss:0.04140
# [279]	eval-logloss:0.04135
# [280]	eval-logloss:0.04132
# [281]	eval-logloss:0.04130
# [282]	eval-logloss:0.04128
# [283]	eval-logloss:0.04127
# [284]	eval-logloss:0.04125
# [285]	eval-logloss:0.04122
# [286]	eval-logloss:0.04120
# [287]	eval-logloss:0.04116
# [288]	eval-logloss:0.04113
# [289]	eval-logloss:0.04111
# [290]	eval-logloss:0.04108
# [291]	eval-logloss:0.04103
# [292]	eval-logloss:0.04101
# [293]	eval-logloss:0.04100
# [294]	eval-logloss:0.04097
# [295]	eval-logloss:0.04092
# [296]	eval-logloss:0.04090
# [297]	eval-logloss:0.04089
# [298]	eval-logloss:0.04087
# [299]	eval-logloss:0.04085
# [300]	eval-logloss:0.04083
# [301]	eval-logloss:0.04082
# [302]	eval-logloss:0.04081
# [303]	eval-logloss:0.04079
# [304]	eval-logloss:0.04076
# [305]	eval-logloss:0.04074
# [306]	eval-logloss:0.04073
# [307]	eval-logloss:0.04070
# [308]	eval-logloss:0.04068
# [309]	eval-logloss:0.04066
# [310]	eval-logloss:0.04065
# [311]	eval-logloss:0.04061
# [312]	eval-logloss:0.04059
# [313]	eval-logloss:0.04058
# [314]	eval-logloss:0.04057
# [315]	eval-logloss:0.04057
# [316]	eval-logloss:0.04056
# [317]	eval-logloss:0.04055
# [318]	eval-logloss:0.04053
# [319]	eval-logloss:0.04052
# [320]	eval-logloss:0.04050
# [321]	eval-logloss:0.04046
# [322]	eval-logloss:0.04046
# [323]	eval-logloss:0.04044
# [324]	eval-logloss:0.04043
# [325]	eval-logloss:0.04041
# [326]	eval-logloss:0.04041
# [327]	eval-logloss:0.04037
# [328]	eval-logloss:0.04034
# [329]	eval-logloss:0.04032
# [330]	eval-logloss:0.04029
# [331]	eval-logloss:0.04027
# [332]	eval-logloss:0.04026
# [333]	eval-logloss:0.04025
# [334]	eval-logloss:0.04024
# [335]	eval-logloss:0.04023
# [336]	eval-logloss:0.04023
# [337]	eval-logloss:0.04022
# [338]	eval-logloss:0.04020
# [339]	eval-logloss:0.04018
# [340]	eval-logloss:0.04017
# [341]	eval-logloss:0.04015
# [342]	eval-logloss:0.04015
# [343]	eval-logloss:0.04013
# [344]	eval-logloss:0.04012
# [345]	eval-logloss:0.04012
# [346]	eval-logloss:0.04011
# [347]	eval-logloss:0.04010
# [348]	eval-logloss:0.04009
# [349]	eval-logloss:0.04007
# [350]	eval-logloss:0.04006
# [351]	eval-logloss:0.04004
# [352]	eval-logloss:0.04004
# [353]	eval-logloss:0.04003
# [354]	eval-logloss:0.04002
# [355]	eval-logloss:0.04001
# [356]	eval-logloss:0.03999
# [357]	eval-logloss:0.03998
# [358]	eval-logloss:0.03998
# [359]	eval-logloss:0.03997
# [360]	eval-logloss:0.03997
# [361]	eval-logloss:0.03996
# [362]	eval-logloss:0.03994
# [363]	eval-logloss:0.03994
# [364]	eval-logloss:0.03994
# [365]	eval-logloss:0.03993
# [366]	eval-logloss:0.03992
# [367]	eval-logloss:0.03991
# [368]	eval-logloss:0.03991
# [369]	eval-logloss:0.03989
# [370]	eval-logloss:0.03989
# [371]	eval-logloss:0.03987
# [372]	eval-logloss:0.03985
# [373]	eval-logloss:0.03985
# [374]	eval-logloss:0.03984
# [375]	eval-logloss:0.03984
# [376]	eval-logloss:0.03983
# [377]	eval-logloss:0.03982
# [378]	eval-logloss:0.03981
# [379]	eval-logloss:0.03981
# [380]	eval-logloss:0.03980
# [381]	eval-logloss:0.03978
# [382]	eval-logloss:0.03977
# [383]	eval-logloss:0.03976
# [384]	eval-logloss:0.03975
# [385]	eval-logloss:0.03975
# [386]	eval-logloss:0.03974
# [387]	eval-logloss:0.03973
# [388]	eval-logloss:0.03973
# [389]	eval-logloss:0.03972
# [390]	eval-logloss:0.03972
# [391]	eval-logloss:0.03971
# [392]	eval-logloss:0.03971
# [393]	eval-logloss:0.03971
# [394]	eval-logloss:0.03971
# [395]	eval-logloss:0.03971
# [396]	eval-logloss:0.03969
# [397]	eval-logloss:0.03969
# [398]	eval-logloss:0.03968
# [399]	eval-logloss:0.03967
# [400]	eval-logloss:0.03967
# [401]	eval-logloss:0.03966
# [402]	eval-logloss:0.03966
# [403]	eval-logloss:0.03966
# [404]	eval-logloss:0.03965
# [405]	eval-logloss:0.03965
# [406]	eval-logloss:0.03964
# [407]	eval-logloss:0.03962
# [408]	eval-logloss:0.03962
# [409]	eval-logloss:0.03961
# [410]	eval-logloss:0.03960
# [411]	eval-logloss:0.03960
# [412]	eval-logloss:0.03960
# [413]	eval-logloss:0.03960
# [414]	eval-logloss:0.03959
# [415]	eval-logloss:0.03959
# [416]	eval-logloss:0.03958
# [417]	eval-logloss:0.03957
# [418]	eval-logloss:0.03957
# [419]	eval-logloss:0.03956
# [420]	eval-logloss:0.03955
# [421]	eval-logloss:0.03954
# [422]	eval-logloss:0.03954
# [423]	eval-logloss:0.03954
# [424]	eval-logloss:0.03953
# [425]	eval-logloss:0.03953
# [426]	eval-logloss:0.03952
# [427]	eval-logloss:0.03951
# [428]	eval-logloss:0.03951
# [429]	eval-logloss:0.03950
# [430]	eval-logloss:0.03950
# [431]	eval-logloss:0.03950
# [432]	eval-logloss:0.03949
# [433]	eval-logloss:0.03949
# [434]	eval-logloss:0.03948
# [435]	eval-logloss:0.03948
# [436]	eval-logloss:0.03947
# [437]	eval-logloss:0.03947
# [438]	eval-logloss:0.03947
# [439]	eval-logloss:0.03946
# [440]	eval-logloss:0.03946
# [441]	eval-logloss:0.03946
# [442]	eval-logloss:0.03946
# [443]	eval-logloss:0.03946
# [444]	eval-logloss:0.03945
# [445]	eval-logloss:0.03945
# [446]	eval-logloss:0.03944
# [447]	eval-logloss:0.03943
# [448]	eval-logloss:0.03943
# [449]	eval-logloss:0.03943
# [450]	eval-logloss:0.03942
# [451]	eval-logloss:0.03941
# [452]	eval-logloss:0.03940
# [453]	eval-logloss:0.03940
# [454]	eval-logloss:0.03939
# [455]	eval-logloss:0.03938
# [456]	eval-logloss:0.03938
# [457]	eval-logloss:0.03938
# [458]	eval-logloss:0.03937
# [459]	eval-logloss:0.03937
# [460]	eval-logloss:0.03936
# [461]	eval-logloss:0.03936
# [462]	eval-logloss:0.03935
# [463]	eval-logloss:0.03935
# [464]	eval-logloss:0.03935
# [465]	eval-logloss:0.03934
# [466]	eval-logloss:0.03934
# [467]	eval-logloss:0.03933
# [468]	eval-logloss:0.03932
# [469]	eval-logloss:0.03932
# [470]	eval-logloss:0.03931
# [471]	eval-logloss:0.03930
# [472]	eval-logloss:0.03929
# [473]	eval-logloss:0.03929
# [474]	eval-logloss:0.03929
# [475]	eval-logloss:0.03928
# [476]	eval-logloss:0.03928
# [477]	eval-logloss:0.03927
# [478]	eval-logloss:0.03927
# [479]	eval-logloss:0.03927
# [480]	eval-logloss:0.03927
# [481]	eval-logloss:0.03926
# [482]	eval-logloss:0.03926
# [483]	eval-logloss:0.03925
# [484]	eval-logloss:0.03925
# [485]	eval-logloss:0.03925
# [486]	eval-logloss:0.03924
# [487]	eval-logloss:0.03924
# [488]	eval-logloss:0.03924
# [489]	eval-logloss:0.03923
# [490]	eval-logloss:0.03923
# [491]	eval-logloss:0.03922
# [492]	eval-logloss:0.03922
# [493]	eval-logloss:0.03922
# [494]	eval-logloss:0.03921
# [495]	eval-logloss:0.03921
# [496]	eval-logloss:0.03920
# [497]	eval-logloss:0.03920
# [498]	eval-logloss:0.03919
# [499]	eval-logloss:0.03919
# [500]	eval-logloss:0.03919
# [501]	eval-logloss:0.03919
# [502]	eval-logloss:0.03918
# [503]	eval-logloss:0.03918
# [504]	eval-logloss:0.03917
# [505]	eval-logloss:0.03916
# [506]	eval-logloss:0.03915
# [507]	eval-logloss:0.03914
# [508]	eval-logloss:0.03914
# [509]	eval-logloss:0.03914
# [510]	eval-logloss:0.03913
# [511]	eval-logloss:0.03913
# [512]	eval-logloss:0.03913
# [513]	eval-logloss:0.03913
# [514]	eval-logloss:0.03913
# [515]	eval-logloss:0.03913
# [516]	eval-logloss:0.03912
# [517]	eval-logloss:0.03912
# [518]	eval-logloss:0.03912
# [519]	eval-logloss:0.03912
# [520]	eval-logloss:0.03912
# [521]	eval-logloss:0.03911
# [522]	eval-logloss:0.03911
# [523]	eval-logloss:0.03910
# [524]	eval-logloss:0.03911
# [525]	eval-logloss:0.03911
# [526]	eval-logloss:0.03910
# [527]	eval-logloss:0.03909
# [528]	eval-logloss:0.03909
# [529]	eval-logloss:0.03909
# [530]	eval-logloss:0.03909
# [531]	eval-logloss:0.03908
# [532]	eval-logloss:0.03908
# [533]	eval-logloss:0.03908
# [534]	eval-logloss:0.03907
# [535]	eval-logloss:0.03907
# [536]	eval-logloss:0.03907
# [537]	eval-logloss:0.03906
# [538]	eval-logloss:0.03906
# [539]	eval-logloss:0.03906
# [540]	eval-logloss:0.03905
# [541]	eval-logloss:0.03905
# [542]	eval-logloss:0.03905
# [543]	eval-logloss:0.03904
# [544]	eval-logloss:0.03904
# [545]	eval-logloss:0.03903
# [546]	eval-logloss:0.03903
# [547]	eval-logloss:0.03903
# [548]	eval-logloss:0.03903
# [549]	eval-logloss:0.03903
# [550]	eval-logloss:0.03903
# [551]	eval-logloss:0.03903
# [552]	eval-logloss:0.03903
# [553]	eval-logloss:0.03903
# [554]	eval-logloss:0.03903
# [555]	eval-logloss:0.03903
# [556]	eval-logloss:0.03903
# [557]	eval-logloss:0.03903
# [558]	eval-logloss:0.03902
# [559]	eval-logloss:0.03902
# [560]	eval-logloss:0.03902
# [561]	eval-logloss:0.03901
# [562]	eval-logloss:0.03901
# [563]	eval-logloss:0.03901
# [564]	eval-logloss:0.03900
# [565]	eval-logloss:0.03899
# [566]	eval-logloss:0.03898
# [567]	eval-logloss:0.03897
# [568]	eval-logloss:0.03897
# [569]	eval-logloss:0.03897
# [570]	eval-logloss:0.03897
# [571]	eval-logloss:0.03896
# [572]	eval-logloss:0.03896
# [573]	eval-logloss:0.03896
# [574]	eval-logloss:0.03896
# [575]	eval-logloss:0.03896
# [576]	eval-logloss:0.03895
# [577]	eval-logloss:0.03895
# [578]	eval-logloss:0.03895
# [579]	eval-logloss:0.03895
# [580]	eval-logloss:0.03894
# [581]	eval-logloss:0.03894
# [582]	eval-logloss:0.03894
# [583]	eval-logloss:0.03893
# [584]	eval-logloss:0.03893
# [585]	eval-logloss:0.03894
# [586]	eval-logloss:0.03893
# [587]	eval-logloss:0.03893
# [588]	eval-logloss:0.03892
# [589]	eval-logloss:0.03892
# [590]	eval-logloss:0.03892
# [591]	eval-logloss:0.03892

# %%
submit_df = pd.DataFrame()
submit_df["id"] = test["id"]
y_preds = clf.predict(X_test_transformed)
pred_classes = lb.inverse_transform(y_preds)
submit_df["class"] = pred_classes
submit_df.to_csv("submission.csv", index=False)
