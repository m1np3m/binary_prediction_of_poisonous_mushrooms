# %% [markdown]
# ## Constants

# %%
import sys, os
import pandas as pd
import numpy as np
import subprocess
import gc
import optuna
from datetime import datetime, timezone
import warnings
import xgboost as xgb
import joblib as jl
from sklearn.model_selection import train_test_split
import warnings
from sklearn.metrics import matthews_corrcoef
from mlflow.models import infer_signature
import mlflow
import random
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelBinarizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

today = datetime.now(timezone.utc).strftime("%Y_%m_%d")
warnings.filterwarnings("ignore")
from hyper_params import (
    mushroom_tuning_2024_08_06_1722934727_params,
)

# helpers
sys.path.append("..")
from helpers.loss_functions import *
from helpers.mlflow import *


SEED = 108
random.seed(SEED)
N_FOLDS = 5
# data
train_path = "../data/mushrooms/train.csv"
test_path = "../data/mushrooms/test.csv"
cache_path = "../data/mushrooms/cache"
# model
is_tunning = True
try:
    rs = subprocess.check_output("nvidia-smi")
    device = "cuda" if rs is not None else "cpu"
except (
    Exception
):  # this command not being found can raise quite a few different errors depending on the configuration
    print("No Nvidia GPU in system!")
    device = "cpu"
goal = "binary:logistic"

# custom metric
objective_dict = {
    "binary:logistic": {
        "metric": {
            "is_custom": False,
            "name": "logloss",
            "fval": None,
        },
        "direction": "minimize",
    }
}
# objective_dict = {
#     "binary:logistic": {
#         "metric": {
#             "is_custom": True,
#             "name": "MCC",
#             "fval": mcc_metric_v2,
#         },
#         "direction": "maximize",
#     }
# }
metric = objective_dict[goal]["metric"]["name"]
is_custom_metric = objective_dict[goal]["metric"]["is_custom"]
fval = objective_dict[goal]["metric"]["fval"]
direction = objective_dict[goal]["direction"]
best_params = {
    "device": device,
    "verbosity": 0,
    "objective": goal,
    # "eval_metric": fval,
}
best_params.update(mushroom_tuning_2024_08_06_1722934727_params)
best_params
# Out:
# {'device': 'cuda',
#  'verbosity': 0,
#  'objective': 'binary:logistic',
#  'tree_method': 'hist',
#  'eta': 0.0696294726051571,
#  'max_depth': 0,
#  'min_child_weight': 1,
#  'gamma': 0.044230646284796976,
#  'subsample': 0.9405269471473167,
#  'colsample_bytree': 0.2999355523666192,
#  'lambda': 0.9746051811186938,
#  'alpha': 4.210861941737071}

# %% [markdown]
# ## Prepare data

# %%
train = pd.read_csv(train_path)
print(f"train size: {train.shape}")
test = pd.read_csv(test_path)
print(f"test size: {test.shape}")
weird_columns = [
    "cap-shape",
    "cap-surface",
    "cap-color",
    "gill-attachment",
    "gill-spacing",
    "gill-color",
    "veil-type",
    "veil-color",
    "has-ring",
    "ring-type",
    "spore-print-color",
    "habitat",
    "does-bruise-or-bleed",
    "stem-root",
    "stem-surface",
    "stem-color",
]

for col in weird_columns:
    allowed_vals = test[col].unique()
    train.loc[~train[col].isin(allowed_vals), col] = "other"
    test.loc[~test[col].isin(allowed_vals), col] = "other"
# Out:
# train size: (3116945, 22)
# test size: (2077964, 21)

# %%
target = "class"

categorical_cols = (
    train.drop(columns=target).select_dtypes(include="object").columns.to_list()
)
for c in categorical_cols:
    train[c] = train[c].astype("category")
    test[c] = test[c].astype("category")
numerical_cols = (
    train.drop(columns="id").select_dtypes(include="number").columns.to_list()
)

# %%
# X_train, X_val, y_train, y_val = train_test_split(
#     train.drop(columns=target),
#     train[target],
#     test_size=0.2,
#     random_state=42,
#     stratify=train[target],
# )
X_test = test
X_train = train.drop(columns=target)
y_train = train[target]
gc.collect()
# Out:
# 132

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# sns.set_theme(font_scale=1.5)
# X_train['cap-shape'].value_counts().sort_values().plot(kind='barh',figsize=(10, 8))
# plt.xlabel("Count", labelpad=14)
# plt.ylabel("Label", labelpad=14)
# plt.title("Orginal Label for product column", y=1.02)

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler




# Create the numerical and categorical pipelines
numerical_pipeline = Pipeline(
    steps=[
        ("num_imputer", SimpleImputer(strategy="mean")),
        ("scaler", StandardScaler()),
        ("minmax", MinMaxScaler()),
    ]
)

categorical_pipeline = Pipeline(
    steps=[
        ("cat_imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder(handle_unknown="ignore")),
    ]
)

# Combine the pipelines into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numerical_pipeline, numerical_cols),
        ("cat", categorical_pipeline, categorical_cols),
    ]
)

# Create the full pipeline with the XGBoost model
data_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
    ]
)

# Preprocess the data
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.transform(X_test)
# X_val_transformed = preprocessor.transform(X_val)
# Binarize the target labels
lb = LabelBinarizer()

y_train_binarized = lb.fit_transform(y_train)
# y_val_binarized = lb.transform(y_val)

# prepare data for training
dtrain = xgb.DMatrix(X_train_transformed, label=y_train_binarized)
# dval = xgb.DMatrix(X_val_transformed, label=y_val_binarized)
dtest = xgb.DMatrix(X_test_transformed)

gc.collect()
# Out:
# 62

# %% [markdown]
# ## CV

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

clf: xgb.XGBClassifier = xgb.XGBClassifier(
    **best_params,
    # callbacks=[xgb.callback.EarlyStopping(50)],
    n_estimators=300,
)

# %%
from tqdm import tqdm
kf = KFold(n_splits=N_FOLDS)
y_preds = []
y_trues = []
for train_index, test_index in tqdm(kf.split(X_train_transformed, y_train_binarized)):
    X_train, X_test = X_train_transformed[train_index], X_train_transformed[test_index]
    y_train, y_test = y_train_binarized[train_index], y_train_binarized[test_index]
    clf.fit(
        X=X_train,
        y=y_train,
        eval_set=[(X_test, y_test)],
    )

    y_pred = clf.predict(X_test)
    y_preds.append(y_pred)
    y_trues.append(y_test)
# Concatenate the predictions and true labels
y_preds_concat = np.concatenate(y_preds)
y_trues_concat = np.concatenate(y_trues)
mcc = matthews_corrcoef(y_trues_concat, y_preds_concat)
print(f"Validation mcc score: {mcc}")
# Out:
# 0it [00:00, ?it/s]
# [0]	validation_0-logloss:0.63812
# [1]	validation_0-logloss:0.58476
# [2]	validation_0-logloss:0.54235
# [3]	validation_0-logloss:0.51615
# [4]	validation_0-logloss:0.48078
# [5]	validation_0-logloss:0.45419
# [6]	validation_0-logloss:0.43975
# [7]	validation_0-logloss:0.40820
# [8]	validation_0-logloss:0.38201
# [9]	validation_0-logloss:0.35452
# [10]	validation_0-logloss:0.33968
# [11]	validation_0-logloss:0.31763
# [12]	validation_0-logloss:0.29763
# [13]	validation_0-logloss:0.27966
# [14]	validation_0-logloss:0.27007
# [15]	validation_0-logloss:0.25598
# [16]	validation_0-logloss:0.24617
# [17]	validation_0-logloss:0.23652
# [18]	validation_0-logloss:0.22713
# [19]	validation_0-logloss:0.21877
# [20]	validation_0-logloss:0.21019
# [21]	validation_0-logloss:0.19890
# [22]	validation_0-logloss:0.18782
# [23]	validation_0-logloss:0.18144
# [24]	validation_0-logloss:0.17155
# [25]	validation_0-logloss:0.16448
# [26]	validation_0-logloss:0.16039
# [27]	validation_0-logloss:0.15160
# [28]	validation_0-logloss:0.14568
# [29]	validation_0-logloss:0.13911
# [30]	validation_0-logloss:0.13261
# [31]	validation_0-logloss:0.12954
# [32]	validation_0-logloss:0.12318
# [33]	validation_0-logloss:0.11946
# [34]	validation_0-logloss:0.11641
# [35]	validation_0-logloss:0.11118
# [36]	validation_0-logloss:0.10770
# [37]	validation_0-logloss:0.10582
# [38]	validation_0-logloss:0.10187
# [39]	validation_0-logloss:0.09879
# [40]	validation_0-logloss:0.09528
# [41]	validation_0-logloss:0.09237
# [42]	validation_0-logloss:0.08878
# [43]	validation_0-logloss:0.08599
# [44]	validation_0-logloss:0.08449
# [45]	validation_0-logloss:0.08270
# [46]	validation_0-logloss:0.08138
# [47]	validation_0-logloss:0.07858
# [48]	validation_0-logloss:0.07640
# [49]	validation_0-logloss:0.07413
# [50]	validation_0-logloss:0.07246
# [51]	validation_0-logloss:0.07011
# [52]	validation_0-logloss:0.06787
# [53]	validation_0-logloss:0.06687
# [54]	validation_0-logloss:0.06524
# [55]	validation_0-logloss:0.06416
# [56]	validation_0-logloss:0.06331
# [57]	validation_0-logloss:0.06196
# [58]	validation_0-logloss:0.06099
# [59]	validation_0-logloss:0.06034
# [60]	validation_0-logloss:0.05963
# [61]	validation_0-logloss:0.05855
# [62]	validation_0-logloss:0.05779
# [63]	validation_0-logloss:0.05697
# [64]	validation_0-logloss:0.05606
# [65]	validation_0-logloss:0.05511
# [66]	validation_0-logloss:0.05452
# [67]	validation_0-logloss:0.05368
# [68]	validation_0-logloss:0.05299
# [69]	validation_0-logloss:0.05206
# [70]	validation_0-logloss:0.05169
# [71]	validation_0-logloss:0.05128
# [72]	validation_0-logloss:0.05067
# [73]	validation_0-logloss:0.05019
# [74]	validation_0-logloss:0.04973
# [75]	validation_0-logloss:0.04933
# [76]	validation_0-logloss:0.04859
# [77]	validation_0-logloss:0.04797
# [78]	validation_0-logloss:0.04749
# [79]	validation_0-logloss:0.04717
# [80]	validation_0-logloss:0.04673
# [81]	validation_0-logloss:0.04613
# [82]	validation_0-logloss:0.04580
# [83]	validation_0-logloss:0.04547
# [84]	validation_0-logloss:0.04512
# [85]	validation_0-logloss:0.04475
# [86]	validation_0-logloss:0.04439
# [87]	validation_0-logloss:0.04417
# [88]	validation_0-logloss:0.04402
# [89]	validation_0-logloss:0.04378
# [90]	validation_0-logloss:0.04340
# [91]	validation_0-logloss:0.04316
# [92]	validation_0-logloss:0.04292
# [93]	validation_0-logloss:0.04265
# [94]	validation_0-logloss:0.04253
# [95]	validation_0-logloss:0.04235
# [96]	validation_0-logloss:0.04217
# [97]	validation_0-logloss:0.04187
# [98]	validation_0-logloss:0.04177
# [99]	validation_0-logloss:0.04168
# [100]	validation_0-logloss:0.04149
# [101]	validation_0-logloss:0.04136
# [102]	validation_0-logloss:0.04124
# [103]	validation_0-logloss:0.04108
# [104]	validation_0-logloss:0.04096
# [105]	validation_0-logloss:0.04084
# [106]	validation_0-logloss:0.04071
# [107]	validation_0-logloss:0.04056
# [108]	validation_0-logloss:0.04049
# [109]	validation_0-logloss:0.04036
# [110]	validation_0-logloss:0.04029
# [111]	validation_0-logloss:0.04020
# [112]	validation_0-logloss:0.04007
# [113]	validation_0-logloss:0.03999
# [114]	validation_0-logloss:0.03985
# [115]	validation_0-logloss:0.03976
# [116]	validation_0-logloss:0.03972
# [117]	validation_0-logloss:0.03960
# [118]	validation_0-logloss:0.03955
# [119]	validation_0-logloss:0.03952
# [120]	validation_0-logloss:0.03949
# [121]	validation_0-logloss:0.03945
# [122]	validation_0-logloss:0.03942
# [123]	validation_0-logloss:0.03937
# [124]	validation_0-logloss:0.03929
# [125]	validation_0-logloss:0.03920
# [126]	validation_0-logloss:0.03916
# [127]	validation_0-logloss:0.03912
# [128]	validation_0-logloss:0.03909
# [129]	validation_0-logloss:0.03904
# [130]	validation_0-logloss:0.03902
# [131]	validation_0-logloss:0.03895
# [132]	validation_0-logloss:0.03892
# [133]	validation_0-logloss:0.03891
# [134]	validation_0-logloss:0.03887
# [135]	validation_0-logloss:0.03883
# [136]	validation_0-logloss:0.03878
# [137]	validation_0-logloss:0.03876
# [138]	validation_0-logloss:0.03874
# [139]	validation_0-logloss:0.03872
# [140]	validation_0-logloss:0.03869
# [141]	validation_0-logloss:0.03866
# [142]	validation_0-logloss:0.03862
# [143]	validation_0-logloss:0.03860
# [144]	validation_0-logloss:0.03854
# [145]	validation_0-logloss:0.03853
# [146]	validation_0-logloss:0.03851
# [147]	validation_0-logloss:0.03846
# [148]	validation_0-logloss:0.03842
# [149]	validation_0-logloss:0.03841
# [150]	validation_0-logloss:0.03837
# [151]	validation_0-logloss:0.03834
# [152]	validation_0-logloss:0.03833
# [153]	validation_0-logloss:0.03832
# [154]	validation_0-logloss:0.03831
# [155]	validation_0-logloss:0.03829
# [156]	validation_0-logloss:0.03826
# [157]	validation_0-logloss:0.03824
# [158]	validation_0-logloss:0.03823
# [159]	validation_0-logloss:0.03819
# [160]	validation_0-logloss:0.03819
# [161]	validation_0-logloss:0.03817
# [162]	validation_0-logloss:0.03816
# [163]	validation_0-logloss:0.03814
# [164]	validation_0-logloss:0.03812
# [165]	validation_0-logloss:0.03810
# [166]	validation_0-logloss:0.03809
# [167]	validation_0-logloss:0.03808
# [168]	validation_0-logloss:0.03807
# [169]	validation_0-logloss:0.03806
# [170]	validation_0-logloss:0.03806
# [171]	validation_0-logloss:0.03804
# [172]	validation_0-logloss:0.03804
# [173]	validation_0-logloss:0.03803
# [174]	validation_0-logloss:0.03802
# [175]	validation_0-logloss:0.03801
# [176]	validation_0-logloss:0.03801
# [177]	validation_0-logloss:0.03801
# [178]	validation_0-logloss:0.03800
# [179]	validation_0-logloss:0.03799
# [180]	validation_0-logloss:0.03798
# [181]	validation_0-logloss:0.03797
# [182]	validation_0-logloss:0.03797
# [183]	validation_0-logloss:0.03796
# [184]	validation_0-logloss:0.03796
# [185]	validation_0-logloss:0.03795
# [186]	validation_0-logloss:0.03795
# [187]	validation_0-logloss:0.03794
# [188]	validation_0-logloss:0.03793
# [189]	validation_0-logloss:0.03793
# [190]	validation_0-logloss:0.03793
# [191]	validation_0-logloss:0.03792
# [192]	validation_0-logloss:0.03791
# [193]	validation_0-logloss:0.03791
# [194]	validation_0-logloss:0.03791
# [195]	validation_0-logloss:0.03791
# [196]	validation_0-logloss:0.03791
# [197]	validation_0-logloss:0.03790
# [198]	validation_0-logloss:0.03789
# [199]	validation_0-logloss:0.03789
# [200]	validation_0-logloss:0.03789
# [201]	validation_0-logloss:0.03789
# [202]	validation_0-logloss:0.03788
# [203]	validation_0-logloss:0.03788
# [204]	validation_0-logloss:0.03788
# [205]	validation_0-logloss:0.03787
# [206]	validation_0-logloss:0.03786
# [207]	validation_0-logloss:0.03786
# [208]	validation_0-logloss:0.03785
# [209]	validation_0-logloss:0.03785
# [210]	validation_0-logloss:0.03784
# [211]	validation_0-logloss:0.03784
# [212]	validation_0-logloss:0.03783
# [213]	validation_0-logloss:0.03783
# [214]	validation_0-logloss:0.03782
# [215]	validation_0-logloss:0.03781
# [216]	validation_0-logloss:0.03781
# [217]	validation_0-logloss:0.03781
# [218]	validation_0-logloss:0.03781
# [219]	validation_0-logloss:0.03780
# [220]	validation_0-logloss:0.03780
# [221]	validation_0-logloss:0.03780
# [222]	validation_0-logloss:0.03780
# [223]	validation_0-logloss:0.03780
# [224]	validation_0-logloss:0.03779
# [225]	validation_0-logloss:0.03779
# [226]	validation_0-logloss:0.03779
# [227]	validation_0-logloss:0.03779
# [228]	validation_0-logloss:0.03778
# [229]	validation_0-logloss:0.03777
# [230]	validation_0-logloss:0.03778
# [231]	validation_0-logloss:0.03777
# [232]	validation_0-logloss:0.03777
# [233]	validation_0-logloss:0.03776
# [234]	validation_0-logloss:0.03776
# [235]	validation_0-logloss:0.03776
# [236]	validation_0-logloss:0.03776
# [237]	validation_0-logloss:0.03775
# [238]	validation_0-logloss:0.03775
# [239]	validation_0-logloss:0.03775
# [240]	validation_0-logloss:0.03774
# [241]	validation_0-logloss:0.03774
# [242]	validation_0-logloss:0.03774
# [243]	validation_0-logloss:0.03774
# [244]	validation_0-logloss:0.03773
# [245]	validation_0-logloss:0.03773
# [246]	validation_0-logloss:0.03773
# [247]	validation_0-logloss:0.03774
# [248]	validation_0-logloss:0.03773
# [249]	validation_0-logloss:0.03773
# [250]	validation_0-logloss:0.03773
# [251]	validation_0-logloss:0.03773
# [252]	validation_0-logloss:0.03773
# [253]	validation_0-logloss:0.03773
# [254]	validation_0-logloss:0.03773
# [255]	validation_0-logloss:0.03773
# [256]	validation_0-logloss:0.03772
# [257]	validation_0-logloss:0.03772
# [258]	validation_0-logloss:0.03772
# [259]	validation_0-logloss:0.03772
# [260]	validation_0-logloss:0.03772
# [261]	validation_0-logloss:0.03772
# [262]	validation_0-logloss:0.03772
# [263]	validation_0-logloss:0.03772
# [264]	validation_0-logloss:0.03772
# [265]	validation_0-logloss:0.03772
# [266]	validation_0-logloss:0.03772
# [267]	validation_0-logloss:0.03772
# [268]	validation_0-logloss:0.03772
# [269]	validation_0-logloss:0.03772
# [270]	validation_0-logloss:0.03772
# [271]	validation_0-logloss:0.03772
# [272]	validation_0-logloss:0.03772
# [273]	validation_0-logloss:0.03772
# [274]	validation_0-logloss:0.03772
# [275]	validation_0-logloss:0.03772
# [276]	validation_0-logloss:0.03772
# [277]	validation_0-logloss:0.03772
# [278]	validation_0-logloss:0.03771
# [279]	validation_0-logloss:0.03772
# [280]	validation_0-logloss:0.03772
# [281]	validation_0-logloss:0.03772
# [282]	validation_0-logloss:0.03771
# [283]	validation_0-logloss:0.03771
# [284]	validation_0-logloss:0.03771
# [285]	validation_0-logloss:0.03771
# [286]	validation_0-logloss:0.03770
# [287]	validation_0-logloss:0.03770
# [288]	validation_0-logloss:0.03770
# [289]	validation_0-logloss:0.03770
# [290]	validation_0-logloss:0.03770
# [291]	validation_0-logloss:0.03770
# [292]	validation_0-logloss:0.03770
# [293]	validation_0-logloss:0.03770
# [294]	validation_0-logloss:0.03770
# [295]	validation_0-logloss:0.03770
# [296]	validation_0-logloss:0.03770
# [297]	validation_0-logloss:0.03770
# [298]	validation_0-logloss:0.03770
# [299]	validation_0-logloss:0.03770
# 1it [00:18, 18.46s/it]
# [0]	validation_0-logloss:0.63840
# [1]	validation_0-logloss:0.58499
# [2]	validation_0-logloss:0.54259
# [3]	validation_0-logloss:0.51637
# [4]	validation_0-logloss:0.48095
# [5]	validation_0-logloss:0.45432
# [6]	validation_0-logloss:0.43990
# [7]	validation_0-logloss:0.40838
# [8]	validation_0-logloss:0.38214
# [9]	validation_0-logloss:0.35462
# [10]	validation_0-logloss:0.33977
# [11]	validation_0-logloss:0.31769
# [12]	validation_0-logloss:0.29769
# [13]	validation_0-logloss:0.27976
# [14]	validation_0-logloss:0.27015
# [15]	validation_0-logloss:0.25604
# [16]	validation_0-logloss:0.24621
# [17]	validation_0-logloss:0.23654
# [18]	validation_0-logloss:0.22713
# [19]	validation_0-logloss:0.21879
# [20]	validation_0-logloss:0.21017
# [21]	validation_0-logloss:0.19885
# [22]	validation_0-logloss:0.18776
# [23]	validation_0-logloss:0.18137
# [24]	validation_0-logloss:0.17148
# [25]	validation_0-logloss:0.16440
# [26]	validation_0-logloss:0.16031
# [27]	validation_0-logloss:0.15153
# [28]	validation_0-logloss:0.14562
# [29]	validation_0-logloss:0.13905
# [30]	validation_0-logloss:0.13254
# [31]	validation_0-logloss:0.12948
# [32]	validation_0-logloss:0.12313
# [33]	validation_0-logloss:0.11941
# [34]	validation_0-logloss:0.11636
# [35]	validation_0-logloss:0.11113
# [36]	validation_0-logloss:0.10766
# [37]	validation_0-logloss:0.10356
# [38]	validation_0-logloss:0.09975
# [39]	validation_0-logloss:0.09677
# [40]	validation_0-logloss:0.09337
# [41]	validation_0-logloss:0.09055
# [42]	validation_0-logloss:0.08709
# [43]	validation_0-logloss:0.08440
# [44]	validation_0-logloss:0.08295
# [45]	validation_0-logloss:0.08122
# [46]	validation_0-logloss:0.07993
# [47]	validation_0-logloss:0.07724
# [48]	validation_0-logloss:0.07513
# [49]	validation_0-logloss:0.07294
# [50]	validation_0-logloss:0.07133
# [51]	validation_0-logloss:0.06905
# [52]	validation_0-logloss:0.06690
# [53]	validation_0-logloss:0.06594
# [54]	validation_0-logloss:0.06433
# [55]	validation_0-logloss:0.06328
# [56]	validation_0-logloss:0.06245
# [57]	validation_0-logloss:0.06116
# [58]	validation_0-logloss:0.06021
# [59]	validation_0-logloss:0.05958
# [60]	validation_0-logloss:0.05889
# [61]	validation_0-logloss:0.05785
# [62]	validation_0-logloss:0.05711
# [63]	validation_0-logloss:0.05631
# [64]	validation_0-logloss:0.05542
# [65]	validation_0-logloss:0.05463
# [66]	validation_0-logloss:0.05405
# [67]	validation_0-logloss:0.05324
# [68]	validation_0-logloss:0.05247
# [69]	validation_0-logloss:0.05158
# [70]	validation_0-logloss:0.05122
# [71]	validation_0-logloss:0.05083
# [72]	validation_0-logloss:0.05023
# [73]	validation_0-logloss:0.04976
# [74]	validation_0-logloss:0.04931
# [75]	validation_0-logloss:0.04892
# [76]	validation_0-logloss:0.04820
# [77]	validation_0-logloss:0.04761
# [78]	validation_0-logloss:0.04714
# [79]	validation_0-logloss:0.04683
# [80]	validation_0-logloss:0.04640
# [81]	validation_0-logloss:0.04583
# [82]	validation_0-logloss:0.04551
# [83]	validation_0-logloss:0.04519
# [84]	validation_0-logloss:0.04485
# [85]	validation_0-logloss:0.04449
# [86]	validation_0-logloss:0.04415
# [87]	validation_0-logloss:0.04394
# [88]	validation_0-logloss:0.04380
# [89]	validation_0-logloss:0.04356
# [90]	validation_0-logloss:0.04319
# [91]	validation_0-logloss:0.04296
# [92]	validation_0-logloss:0.04272
# [93]	validation_0-logloss:0.04246
# [94]	validation_0-logloss:0.04234
# [95]	validation_0-logloss:0.04217
# [96]	validation_0-logloss:0.04198
# [97]	validation_0-logloss:0.04170
# [98]	validation_0-logloss:0.04160
# [99]	validation_0-logloss:0.04151
# [100]	validation_0-logloss:0.04133
# [101]	validation_0-logloss:0.04120
# [102]	validation_0-logloss:0.04108
# [103]	validation_0-logloss:0.04091
# [104]	validation_0-logloss:0.04080
# [105]	validation_0-logloss:0.04069
# [106]	validation_0-logloss:0.04057
# [107]	validation_0-logloss:0.04044
# [108]	validation_0-logloss:0.04035
# [109]	validation_0-logloss:0.04022
# [110]	validation_0-logloss:0.04016
# [111]	validation_0-logloss:0.04007
# [112]	validation_0-logloss:0.03995
# [113]	validation_0-logloss:0.03987
# [114]	validation_0-logloss:0.03975
# [115]	validation_0-logloss:0.03965
# [116]	validation_0-logloss:0.03961
# [117]	validation_0-logloss:0.03951
# [118]	validation_0-logloss:0.03945
# [119]	validation_0-logloss:0.03943
# [120]	validation_0-logloss:0.03939
# [121]	validation_0-logloss:0.03935
# [122]	validation_0-logloss:0.03933
# [123]	validation_0-logloss:0.03928
# [124]	validation_0-logloss:0.03920
# [125]	validation_0-logloss:0.03912
# [126]	validation_0-logloss:0.03908
# [127]	validation_0-logloss:0.03904
# [128]	validation_0-logloss:0.03901
# [129]	validation_0-logloss:0.03896
# [130]	validation_0-logloss:0.03894
# [131]	validation_0-logloss:0.03887
# [132]	validation_0-logloss:0.03885
# [133]	validation_0-logloss:0.03883
# [134]	validation_0-logloss:0.03880
# [135]	validation_0-logloss:0.03876
# [136]	validation_0-logloss:0.03871
# [137]	validation_0-logloss:0.03869
# [138]	validation_0-logloss:0.03867
# [139]	validation_0-logloss:0.03865
# [140]	validation_0-logloss:0.03862
# [141]	validation_0-logloss:0.03859
# [142]	validation_0-logloss:0.03856
# [143]	validation_0-logloss:0.03854
# [144]	validation_0-logloss:0.03849
# [145]	validation_0-logloss:0.03848
# [146]	validation_0-logloss:0.03846
# [147]	validation_0-logloss:0.03841
# [148]	validation_0-logloss:0.03838
# [149]	validation_0-logloss:0.03836
# [150]	validation_0-logloss:0.03833
# [151]	validation_0-logloss:0.03831
# [152]	validation_0-logloss:0.03829
# [153]	validation_0-logloss:0.03828
# [154]	validation_0-logloss:0.03827
# [155]	validation_0-logloss:0.03825
# [156]	validation_0-logloss:0.03822
# [157]	validation_0-logloss:0.03820
# [158]	validation_0-logloss:0.03819
# [159]	validation_0-logloss:0.03816
# [160]	validation_0-logloss:0.03816
# [161]	validation_0-logloss:0.03814
# [162]	validation_0-logloss:0.03813
# [163]	validation_0-logloss:0.03812
# [164]	validation_0-logloss:0.03810
# [165]	validation_0-logloss:0.03809
# [166]	validation_0-logloss:0.03808
# [167]	validation_0-logloss:0.03806
# [168]	validation_0-logloss:0.03806
# [169]	validation_0-logloss:0.03805
# [170]	validation_0-logloss:0.03804
# [171]	validation_0-logloss:0.03803
# [172]	validation_0-logloss:0.03802
# [173]	validation_0-logloss:0.03802
# [174]	validation_0-logloss:0.03801
# [175]	validation_0-logloss:0.03800
# [176]	validation_0-logloss:0.03800
# [177]	validation_0-logloss:0.03799
# [178]	validation_0-logloss:0.03799
# [179]	validation_0-logloss:0.03798
# [180]	validation_0-logloss:0.03797
# [181]	validation_0-logloss:0.03796
# [182]	validation_0-logloss:0.03796
# [183]	validation_0-logloss:0.03796
# [184]	validation_0-logloss:0.03796
# [185]	validation_0-logloss:0.03795
# [186]	validation_0-logloss:0.03794
# [187]	validation_0-logloss:0.03793
# [188]	validation_0-logloss:0.03793
# [189]	validation_0-logloss:0.03792
# [190]	validation_0-logloss:0.03792
# [191]	validation_0-logloss:0.03791
# [192]	validation_0-logloss:0.03791
# [193]	validation_0-logloss:0.03790
# [194]	validation_0-logloss:0.03790
# [195]	validation_0-logloss:0.03790
# [196]	validation_0-logloss:0.03789
# [197]	validation_0-logloss:0.03788
# [198]	validation_0-logloss:0.03788
# [199]	validation_0-logloss:0.03787
# [200]	validation_0-logloss:0.03787
# [201]	validation_0-logloss:0.03787
# [202]	validation_0-logloss:0.03787
# [203]	validation_0-logloss:0.03787
# [204]	validation_0-logloss:0.03786
# [205]	validation_0-logloss:0.03786
# [206]	validation_0-logloss:0.03785
# [207]	validation_0-logloss:0.03785
# [208]	validation_0-logloss:0.03784
# [209]	validation_0-logloss:0.03784
# [210]	validation_0-logloss:0.03784
# [211]	validation_0-logloss:0.03783
# [212]	validation_0-logloss:0.03783
# [213]	validation_0-logloss:0.03782
# [214]	validation_0-logloss:0.03782
# [215]	validation_0-logloss:0.03782
# [216]	validation_0-logloss:0.03782
# [217]	validation_0-logloss:0.03781
# [218]	validation_0-logloss:0.03781
# [219]	validation_0-logloss:0.03781
# [220]	validation_0-logloss:0.03780
# [221]	validation_0-logloss:0.03780
# [222]	validation_0-logloss:0.03780
# [223]	validation_0-logloss:0.03780
# [224]	validation_0-logloss:0.03780
# [225]	validation_0-logloss:0.03780
# [226]	validation_0-logloss:0.03780
# [227]	validation_0-logloss:0.03780
# [228]	validation_0-logloss:0.03779
# [229]	validation_0-logloss:0.03779
# [230]	validation_0-logloss:0.03779
# [231]	validation_0-logloss:0.03779
# [232]	validation_0-logloss:0.03778
# [233]	validation_0-logloss:0.03778
# [234]	validation_0-logloss:0.03778
# [235]	validation_0-logloss:0.03777
# [236]	validation_0-logloss:0.03777
# [237]	validation_0-logloss:0.03777
# [238]	validation_0-logloss:0.03777
# [239]	validation_0-logloss:0.03777
# [240]	validation_0-logloss:0.03777
# [241]	validation_0-logloss:0.03777
# [242]	validation_0-logloss:0.03777
# [243]	validation_0-logloss:0.03776
# [244]	validation_0-logloss:0.03776
# [245]	validation_0-logloss:0.03776
# [246]	validation_0-logloss:0.03776
# [247]	validation_0-logloss:0.03776
# [248]	validation_0-logloss:0.03776
# [249]	validation_0-logloss:0.03777
# [250]	validation_0-logloss:0.03776
# [251]	validation_0-logloss:0.03776
# [252]	validation_0-logloss:0.03776
# [253]	validation_0-logloss:0.03776
# [254]	validation_0-logloss:0.03776
# [255]	validation_0-logloss:0.03776
# [256]	validation_0-logloss:0.03776
# [257]	validation_0-logloss:0.03775
# [258]	validation_0-logloss:0.03775
# [259]	validation_0-logloss:0.03775
# [260]	validation_0-logloss:0.03775
# [261]	validation_0-logloss:0.03775
# [262]	validation_0-logloss:0.03776
# [263]	validation_0-logloss:0.03775
# [264]	validation_0-logloss:0.03775
# [265]	validation_0-logloss:0.03775
# [266]	validation_0-logloss:0.03775
# [267]	validation_0-logloss:0.03775
# [268]	validation_0-logloss:0.03775
# [269]	validation_0-logloss:0.03775
# [270]	validation_0-logloss:0.03775
# [271]	validation_0-logloss:0.03775
# [272]	validation_0-logloss:0.03775
# [273]	validation_0-logloss:0.03775
# [274]	validation_0-logloss:0.03775
# [275]	validation_0-logloss:0.03775
# [276]	validation_0-logloss:0.03775
# [277]	validation_0-logloss:0.03775
# [278]	validation_0-logloss:0.03775
# [279]	validation_0-logloss:0.03775
# [280]	validation_0-logloss:0.03775
# [281]	validation_0-logloss:0.03775
# [282]	validation_0-logloss:0.03775
# [283]	validation_0-logloss:0.03775
# [284]	validation_0-logloss:0.03775
# [285]	validation_0-logloss:0.03775
# [286]	validation_0-logloss:0.03775
# [287]	validation_0-logloss:0.03775
# [288]	validation_0-logloss:0.03775
# [289]	validation_0-logloss:0.03775
# [290]	validation_0-logloss:0.03776
# [291]	validation_0-logloss:0.03775
# [292]	validation_0-logloss:0.03776
# [293]	validation_0-logloss:0.03776
# [294]	validation_0-logloss:0.03776
# [295]	validation_0-logloss:0.03776
# [296]	validation_0-logloss:0.03776
# [297]	validation_0-logloss:0.03776
# [298]	validation_0-logloss:0.03776
# [299]	validation_0-logloss:0.03776
# 2it [00:36, 18.43s/it]
# [0]	validation_0-logloss:0.63830
# [1]	validation_0-logloss:0.58490
# [2]	validation_0-logloss:0.54244
# [3]	validation_0-logloss:0.51622
# [4]	validation_0-logloss:0.48086
# [5]	validation_0-logloss:0.45429
# [6]	validation_0-logloss:0.43988
# [7]	validation_0-logloss:0.40836
# [8]	validation_0-logloss:0.38211
# [9]	validation_0-logloss:0.35462
# [10]	validation_0-logloss:0.33979
# [11]	validation_0-logloss:0.31773
# [12]	validation_0-logloss:0.29769
# [13]	validation_0-logloss:0.27970
# [14]	validation_0-logloss:0.27012
# [15]	validation_0-logloss:0.25602
# [16]	validation_0-logloss:0.24621
# [17]	validation_0-logloss:0.23657
# [18]	validation_0-logloss:0.22715
# [19]	validation_0-logloss:0.21880
# [20]	validation_0-logloss:0.21017
# [21]	validation_0-logloss:0.19884
# [22]	validation_0-logloss:0.18776
# [23]	validation_0-logloss:0.18138
# [24]	validation_0-logloss:0.17146
# [25]	validation_0-logloss:0.16439
# [26]	validation_0-logloss:0.16031
# [27]	validation_0-logloss:0.15152
# [28]	validation_0-logloss:0.14559
# [29]	validation_0-logloss:0.13900
# [30]	validation_0-logloss:0.13248
# [31]	validation_0-logloss:0.12942
# [32]	validation_0-logloss:0.12306
# [33]	validation_0-logloss:0.11932
# [34]	validation_0-logloss:0.11625
# [35]	validation_0-logloss:0.11102
# [36]	validation_0-logloss:0.10754
# [37]	validation_0-logloss:0.10343
# [38]	validation_0-logloss:0.09960
# [39]	validation_0-logloss:0.09662
# [40]	validation_0-logloss:0.09322
# [41]	validation_0-logloss:0.09039
# [42]	validation_0-logloss:0.08692
# [43]	validation_0-logloss:0.08422
# [44]	validation_0-logloss:0.08276
# [45]	validation_0-logloss:0.08103
# [46]	validation_0-logloss:0.07976
# [47]	validation_0-logloss:0.07704
# [48]	validation_0-logloss:0.07493
# [49]	validation_0-logloss:0.07275
# [50]	validation_0-logloss:0.07113
# [51]	validation_0-logloss:0.06885
# [52]	validation_0-logloss:0.06669
# [53]	validation_0-logloss:0.06572
# [54]	validation_0-logloss:0.06412
# [55]	validation_0-logloss:0.06307
# [56]	validation_0-logloss:0.06225
# [57]	validation_0-logloss:0.06100
# [58]	validation_0-logloss:0.06006
# [59]	validation_0-logloss:0.05942
# [60]	validation_0-logloss:0.05873
# [61]	validation_0-logloss:0.05824
# [62]	validation_0-logloss:0.05747
# [63]	validation_0-logloss:0.05664
# [64]	validation_0-logloss:0.05573
# [65]	validation_0-logloss:0.05479
# [66]	validation_0-logloss:0.05420
# [67]	validation_0-logloss:0.05336
# [68]	validation_0-logloss:0.05266
# [69]	validation_0-logloss:0.05173
# [70]	validation_0-logloss:0.05136
# [71]	validation_0-logloss:0.05096
# [72]	validation_0-logloss:0.05035
# [73]	validation_0-logloss:0.04987
# [74]	validation_0-logloss:0.04942
# [75]	validation_0-logloss:0.04903
# [76]	validation_0-logloss:0.04829
# [77]	validation_0-logloss:0.04770
# [78]	validation_0-logloss:0.04722
# [79]	validation_0-logloss:0.04689
# [80]	validation_0-logloss:0.04645
# [81]	validation_0-logloss:0.04585
# [82]	validation_0-logloss:0.04552
# [83]	validation_0-logloss:0.04520
# [84]	validation_0-logloss:0.04485
# [85]	validation_0-logloss:0.04447
# [86]	validation_0-logloss:0.04411
# [87]	validation_0-logloss:0.04389
# [88]	validation_0-logloss:0.04374
# [89]	validation_0-logloss:0.04350
# [90]	validation_0-logloss:0.04313
# [91]	validation_0-logloss:0.04288
# [92]	validation_0-logloss:0.04264
# [93]	validation_0-logloss:0.04237
# [94]	validation_0-logloss:0.04224
# [95]	validation_0-logloss:0.04206
# [96]	validation_0-logloss:0.04188
# [97]	validation_0-logloss:0.04158
# [98]	validation_0-logloss:0.04148
# [99]	validation_0-logloss:0.04139
# [100]	validation_0-logloss:0.04120
# [101]	validation_0-logloss:0.04108
# [102]	validation_0-logloss:0.04095
# [103]	validation_0-logloss:0.04078
# [104]	validation_0-logloss:0.04067
# [105]	validation_0-logloss:0.04055
# [106]	validation_0-logloss:0.04042
# [107]	validation_0-logloss:0.04028
# [108]	validation_0-logloss:0.04019
# [109]	validation_0-logloss:0.04006
# [110]	validation_0-logloss:0.04001
# [111]	validation_0-logloss:0.03991
# [112]	validation_0-logloss:0.03978
# [113]	validation_0-logloss:0.03970
# [114]	validation_0-logloss:0.03956
# [115]	validation_0-logloss:0.03946
# [116]	validation_0-logloss:0.03941
# [117]	validation_0-logloss:0.03930
# [118]	validation_0-logloss:0.03925
# [119]	validation_0-logloss:0.03923
# [120]	validation_0-logloss:0.03919
# [121]	validation_0-logloss:0.03915
# [122]	validation_0-logloss:0.03912
# [123]	validation_0-logloss:0.03907
# [124]	validation_0-logloss:0.03899
# [125]	validation_0-logloss:0.03890
# [126]	validation_0-logloss:0.03886
# [127]	validation_0-logloss:0.03883
# [128]	validation_0-logloss:0.03879
# [129]	validation_0-logloss:0.03874
# [130]	validation_0-logloss:0.03872
# [131]	validation_0-logloss:0.03865
# [132]	validation_0-logloss:0.03863
# [133]	validation_0-logloss:0.03861
# [134]	validation_0-logloss:0.03858
# [135]	validation_0-logloss:0.03853
# [136]	validation_0-logloss:0.03848
# [137]	validation_0-logloss:0.03845
# [138]	validation_0-logloss:0.03844
# [139]	validation_0-logloss:0.03841
# [140]	validation_0-logloss:0.03838
# [141]	validation_0-logloss:0.03835
# [142]	validation_0-logloss:0.03832
# [143]	validation_0-logloss:0.03830
# [144]	validation_0-logloss:0.03824
# [145]	validation_0-logloss:0.03822
# [146]	validation_0-logloss:0.03820
# [147]	validation_0-logloss:0.03816
# [148]	validation_0-logloss:0.03812
# [149]	validation_0-logloss:0.03810
# [150]	validation_0-logloss:0.03807
# [151]	validation_0-logloss:0.03804
# [152]	validation_0-logloss:0.03802
# [153]	validation_0-logloss:0.03801
# [154]	validation_0-logloss:0.03800
# [155]	validation_0-logloss:0.03798
# [156]	validation_0-logloss:0.03796
# [157]	validation_0-logloss:0.03794
# [158]	validation_0-logloss:0.03792
# [159]	validation_0-logloss:0.03789
# [160]	validation_0-logloss:0.03788
# [161]	validation_0-logloss:0.03787
# [162]	validation_0-logloss:0.03786
# [163]	validation_0-logloss:0.03784
# [164]	validation_0-logloss:0.03782
# [165]	validation_0-logloss:0.03780
# [166]	validation_0-logloss:0.03780
# [167]	validation_0-logloss:0.03778
# [168]	validation_0-logloss:0.03777
# [169]	validation_0-logloss:0.03776
# [170]	validation_0-logloss:0.03776
# [171]	validation_0-logloss:0.03774
# [172]	validation_0-logloss:0.03774
# [173]	validation_0-logloss:0.03773
# [174]	validation_0-logloss:0.03772
# [175]	validation_0-logloss:0.03772
# [176]	validation_0-logloss:0.03771
# [177]	validation_0-logloss:0.03771
# [178]	validation_0-logloss:0.03770
# [179]	validation_0-logloss:0.03769
# [180]	validation_0-logloss:0.03768
# [181]	validation_0-logloss:0.03767
# [182]	validation_0-logloss:0.03767
# [183]	validation_0-logloss:0.03767
# [184]	validation_0-logloss:0.03766
# [185]	validation_0-logloss:0.03766
# [186]	validation_0-logloss:0.03765
# [187]	validation_0-logloss:0.03764
# [188]	validation_0-logloss:0.03764
# [189]	validation_0-logloss:0.03763
# [190]	validation_0-logloss:0.03762
# [191]	validation_0-logloss:0.03762
# [192]	validation_0-logloss:0.03761
# [193]	validation_0-logloss:0.03761
# [194]	validation_0-logloss:0.03760
# [195]	validation_0-logloss:0.03760
# [196]	validation_0-logloss:0.03760
# [197]	validation_0-logloss:0.03759
# [198]	validation_0-logloss:0.03758
# [199]	validation_0-logloss:0.03758
# [200]	validation_0-logloss:0.03758
# [201]	validation_0-logloss:0.03758
# [202]	validation_0-logloss:0.03757
# [203]	validation_0-logloss:0.03757
# [204]	validation_0-logloss:0.03756
# [205]	validation_0-logloss:0.03755
# [206]	validation_0-logloss:0.03754
# [207]	validation_0-logloss:0.03754
# [208]	validation_0-logloss:0.03753
# [209]	validation_0-logloss:0.03753
# [210]	validation_0-logloss:0.03753
# [211]	validation_0-logloss:0.03752
# [212]	validation_0-logloss:0.03752
# [213]	validation_0-logloss:0.03752
# [214]	validation_0-logloss:0.03751
# [215]	validation_0-logloss:0.03751
# [216]	validation_0-logloss:0.03751
# [217]	validation_0-logloss:0.03750
# [218]	validation_0-logloss:0.03750
# [219]	validation_0-logloss:0.03749
# [220]	validation_0-logloss:0.03748
# [221]	validation_0-logloss:0.03748
# [222]	validation_0-logloss:0.03748
# [223]	validation_0-logloss:0.03748
# [224]	validation_0-logloss:0.03748
# [225]	validation_0-logloss:0.03748
# [226]	validation_0-logloss:0.03747
# [227]	validation_0-logloss:0.03747
# [228]	validation_0-logloss:0.03747
# [229]	validation_0-logloss:0.03747
# [230]	validation_0-logloss:0.03747
# [231]	validation_0-logloss:0.03746
# [232]	validation_0-logloss:0.03746
# [233]	validation_0-logloss:0.03745
# [234]	validation_0-logloss:0.03745
# [235]	validation_0-logloss:0.03745
# [236]	validation_0-logloss:0.03744
# [237]	validation_0-logloss:0.03744
# [238]	validation_0-logloss:0.03744
# [239]	validation_0-logloss:0.03744
# [240]	validation_0-logloss:0.03744
# [241]	validation_0-logloss:0.03743
# [242]	validation_0-logloss:0.03743
# [243]	validation_0-logloss:0.03743
# [244]	validation_0-logloss:0.03742
# [245]	validation_0-logloss:0.03742
# [246]	validation_0-logloss:0.03742
# [247]	validation_0-logloss:0.03743
# [248]	validation_0-logloss:0.03743
# [249]	validation_0-logloss:0.03743
# [250]	validation_0-logloss:0.03743
# [251]	validation_0-logloss:0.03743
# [252]	validation_0-logloss:0.03742
# [253]	validation_0-logloss:0.03742
# [254]	validation_0-logloss:0.03742
# [255]	validation_0-logloss:0.03742
# [256]	validation_0-logloss:0.03742
# [257]	validation_0-logloss:0.03741
# [258]	validation_0-logloss:0.03741
# [259]	validation_0-logloss:0.03741
# [260]	validation_0-logloss:0.03741
# [261]	validation_0-logloss:0.03741
# [262]	validation_0-logloss:0.03741
# [263]	validation_0-logloss:0.03741
# [264]	validation_0-logloss:0.03741
# [265]	validation_0-logloss:0.03741
# [266]	validation_0-logloss:0.03741
# [267]	validation_0-logloss:0.03741
# [268]	validation_0-logloss:0.03741
# [269]	validation_0-logloss:0.03741
# [270]	validation_0-logloss:0.03741
# [271]	validation_0-logloss:0.03740
# [272]	validation_0-logloss:0.03741
# [273]	validation_0-logloss:0.03741
# [274]	validation_0-logloss:0.03740
# [275]	validation_0-logloss:0.03740
# [276]	validation_0-logloss:0.03740
# [277]	validation_0-logloss:0.03740
# [278]	validation_0-logloss:0.03740
# [279]	validation_0-logloss:0.03740
# [280]	validation_0-logloss:0.03740
# [281]	validation_0-logloss:0.03740
# [282]	validation_0-logloss:0.03740
# [283]	validation_0-logloss:0.03740
# [284]	validation_0-logloss:0.03740
# [285]	validation_0-logloss:0.03740
# [286]	validation_0-logloss:0.03740
# [287]	validation_0-logloss:0.03740
# [288]	validation_0-logloss:0.03740
# [289]	validation_0-logloss:0.03740
# [290]	validation_0-logloss:0.03740
# [291]	validation_0-logloss:0.03740
# [292]	validation_0-logloss:0.03740
# [293]	validation_0-logloss:0.03740
# [294]	validation_0-logloss:0.03740
# [295]	validation_0-logloss:0.03740
# [296]	validation_0-logloss:0.03740
# [297]	validation_0-logloss:0.03740
# [298]	validation_0-logloss:0.03740
# [299]	validation_0-logloss:0.03740
# 3it [00:55, 18.41s/it]
# [0]	validation_0-logloss:0.63834
# [1]	validation_0-logloss:0.58497
# [2]	validation_0-logloss:0.54256
# [3]	validation_0-logloss:0.51640
# [4]	validation_0-logloss:0.48106
# [5]	validation_0-logloss:0.45443
# [6]	validation_0-logloss:0.43999
# [7]	validation_0-logloss:0.40850
# [8]	validation_0-logloss:0.38228
# [9]	validation_0-logloss:0.35480
# [10]	validation_0-logloss:0.33994
# [11]	validation_0-logloss:0.31787
# [12]	validation_0-logloss:0.29786
# [13]	validation_0-logloss:0.27990
# [14]	validation_0-logloss:0.27030
# [15]	validation_0-logloss:0.25620
# [16]	validation_0-logloss:0.24639
# [17]	validation_0-logloss:0.23671
# [18]	validation_0-logloss:0.22730
# [19]	validation_0-logloss:0.21894
# [20]	validation_0-logloss:0.21033
# [21]	validation_0-logloss:0.19901
# [22]	validation_0-logloss:0.18793
# [23]	validation_0-logloss:0.18155
# [24]	validation_0-logloss:0.17166
# [25]	validation_0-logloss:0.16458
# [26]	validation_0-logloss:0.16050
# [27]	validation_0-logloss:0.15171
# [28]	validation_0-logloss:0.14578
# [29]	validation_0-logloss:0.13922
# [30]	validation_0-logloss:0.13272
# [31]	validation_0-logloss:0.12989
# [32]	validation_0-logloss:0.12351
# [33]	validation_0-logloss:0.11977
# [34]	validation_0-logloss:0.11671
# [35]	validation_0-logloss:0.11147
# [36]	validation_0-logloss:0.10798
# [37]	validation_0-logloss:0.10385
# [38]	validation_0-logloss:0.10004
# [39]	validation_0-logloss:0.09706
# [40]	validation_0-logloss:0.09366
# [41]	validation_0-logloss:0.09083
# [42]	validation_0-logloss:0.08735
# [43]	validation_0-logloss:0.08465
# [44]	validation_0-logloss:0.08319
# [45]	validation_0-logloss:0.08146
# [46]	validation_0-logloss:0.08017
# [47]	validation_0-logloss:0.07745
# [48]	validation_0-logloss:0.07534
# [49]	validation_0-logloss:0.07315
# [50]	validation_0-logloss:0.07153
# [51]	validation_0-logloss:0.06925
# [52]	validation_0-logloss:0.06709
# [53]	validation_0-logloss:0.06612
# [54]	validation_0-logloss:0.06452
# [55]	validation_0-logloss:0.06348
# [56]	validation_0-logloss:0.06266
# [57]	validation_0-logloss:0.06136
# [58]	validation_0-logloss:0.06043
# [59]	validation_0-logloss:0.05979
# [60]	validation_0-logloss:0.05911
# [61]	validation_0-logloss:0.05806
# [62]	validation_0-logloss:0.05732
# [63]	validation_0-logloss:0.05652
# [64]	validation_0-logloss:0.05563
# [65]	validation_0-logloss:0.05473
# [66]	validation_0-logloss:0.05415
# [67]	validation_0-logloss:0.05334
# [68]	validation_0-logloss:0.05260
# [69]	validation_0-logloss:0.05171
# [70]	validation_0-logloss:0.05135
# [71]	validation_0-logloss:0.05097
# [72]	validation_0-logloss:0.05038
# [73]	validation_0-logloss:0.04993
# [74]	validation_0-logloss:0.04949
# [75]	validation_0-logloss:0.04911
# [76]	validation_0-logloss:0.04839
# [77]	validation_0-logloss:0.04780
# [78]	validation_0-logloss:0.04734
# [79]	validation_0-logloss:0.04704
# [80]	validation_0-logloss:0.04662
# [81]	validation_0-logloss:0.04605
# [82]	validation_0-logloss:0.04573
# [83]	validation_0-logloss:0.04542
# [84]	validation_0-logloss:0.04509
# [85]	validation_0-logloss:0.04473
# [86]	validation_0-logloss:0.04439
# [87]	validation_0-logloss:0.04418
# [88]	validation_0-logloss:0.04404
# [89]	validation_0-logloss:0.04381
# [90]	validation_0-logloss:0.04345
# [91]	validation_0-logloss:0.04322
# [92]	validation_0-logloss:0.04298
# [93]	validation_0-logloss:0.04272
# [94]	validation_0-logloss:0.04261
# [95]	validation_0-logloss:0.04244
# [96]	validation_0-logloss:0.04226
# [97]	validation_0-logloss:0.04198
# [98]	validation_0-logloss:0.04188
# [99]	validation_0-logloss:0.04179
# [100]	validation_0-logloss:0.04161
# [101]	validation_0-logloss:0.04148
# [102]	validation_0-logloss:0.04136
# [103]	validation_0-logloss:0.04121
# [104]	validation_0-logloss:0.04110
# [105]	validation_0-logloss:0.04099
# [106]	validation_0-logloss:0.04087
# [107]	validation_0-logloss:0.04074
# [108]	validation_0-logloss:0.04065
# [109]	validation_0-logloss:0.04053
# [110]	validation_0-logloss:0.04046
# [111]	validation_0-logloss:0.04039
# [112]	validation_0-logloss:0.04026
# [113]	validation_0-logloss:0.04018
# [114]	validation_0-logloss:0.04006
# [115]	validation_0-logloss:0.03997
# [116]	validation_0-logloss:0.03994
# [117]	validation_0-logloss:0.03983
# [118]	validation_0-logloss:0.03978
# [119]	validation_0-logloss:0.03976
# [120]	validation_0-logloss:0.03973
# [121]	validation_0-logloss:0.03969
# [122]	validation_0-logloss:0.03966
# [123]	validation_0-logloss:0.03961
# [124]	validation_0-logloss:0.03953
# [125]	validation_0-logloss:0.03945
# [126]	validation_0-logloss:0.03941
# [127]	validation_0-logloss:0.03938
# [128]	validation_0-logloss:0.03935
# [129]	validation_0-logloss:0.03929
# [130]	validation_0-logloss:0.03927
# [131]	validation_0-logloss:0.03921
# [132]	validation_0-logloss:0.03918
# [133]	validation_0-logloss:0.03917
# [134]	validation_0-logloss:0.03913
# [135]	validation_0-logloss:0.03909
# [136]	validation_0-logloss:0.03903
# [137]	validation_0-logloss:0.03901
# [138]	validation_0-logloss:0.03900
# [139]	validation_0-logloss:0.03898
# [140]	validation_0-logloss:0.03895
# [141]	validation_0-logloss:0.03892
# [142]	validation_0-logloss:0.03889
# [143]	validation_0-logloss:0.03886
# [144]	validation_0-logloss:0.03881
# [145]	validation_0-logloss:0.03880
# [146]	validation_0-logloss:0.03878
# [147]	validation_0-logloss:0.03874
# [148]	validation_0-logloss:0.03870
# [149]	validation_0-logloss:0.03869
# [150]	validation_0-logloss:0.03866
# [151]	validation_0-logloss:0.03863
# [152]	validation_0-logloss:0.03860
# [153]	validation_0-logloss:0.03859
# [154]	validation_0-logloss:0.03859
# [155]	validation_0-logloss:0.03856
# [156]	validation_0-logloss:0.03854
# [157]	validation_0-logloss:0.03852
# [158]	validation_0-logloss:0.03851
# [159]	validation_0-logloss:0.03848
# [160]	validation_0-logloss:0.03848
# [161]	validation_0-logloss:0.03846
# [162]	validation_0-logloss:0.03845
# [163]	validation_0-logloss:0.03844
# [164]	validation_0-logloss:0.03843
# [165]	validation_0-logloss:0.03841
# [166]	validation_0-logloss:0.03840
# [167]	validation_0-logloss:0.03839
# [168]	validation_0-logloss:0.03838
# [169]	validation_0-logloss:0.03838
# [170]	validation_0-logloss:0.03837
# [171]	validation_0-logloss:0.03836
# [172]	validation_0-logloss:0.03835
# [173]	validation_0-logloss:0.03835
# [174]	validation_0-logloss:0.03834
# [175]	validation_0-logloss:0.03833
# [176]	validation_0-logloss:0.03833
# [177]	validation_0-logloss:0.03833
# [178]	validation_0-logloss:0.03832
# [179]	validation_0-logloss:0.03831
# [180]	validation_0-logloss:0.03830
# [181]	validation_0-logloss:0.03830
# [182]	validation_0-logloss:0.03829
# [183]	validation_0-logloss:0.03829
# [184]	validation_0-logloss:0.03829
# [185]	validation_0-logloss:0.03828
# [186]	validation_0-logloss:0.03828
# [187]	validation_0-logloss:0.03827
# [188]	validation_0-logloss:0.03826
# [189]	validation_0-logloss:0.03826
# [190]	validation_0-logloss:0.03826
# [191]	validation_0-logloss:0.03825
# [192]	validation_0-logloss:0.03825
# [193]	validation_0-logloss:0.03824
# [194]	validation_0-logloss:0.03824
# [195]	validation_0-logloss:0.03824
# [196]	validation_0-logloss:0.03823
# [197]	validation_0-logloss:0.03823
# [198]	validation_0-logloss:0.03822
# [199]	validation_0-logloss:0.03822
# [200]	validation_0-logloss:0.03822
# [201]	validation_0-logloss:0.03821
# [202]	validation_0-logloss:0.03821
# [203]	validation_0-logloss:0.03821
# [204]	validation_0-logloss:0.03820
# [205]	validation_0-logloss:0.03820
# [206]	validation_0-logloss:0.03819
# [207]	validation_0-logloss:0.03819
# [208]	validation_0-logloss:0.03818
# [209]	validation_0-logloss:0.03818
# [210]	validation_0-logloss:0.03818
# [211]	validation_0-logloss:0.03817
# [212]	validation_0-logloss:0.03817
# [213]	validation_0-logloss:0.03816
# [214]	validation_0-logloss:0.03816
# [215]	validation_0-logloss:0.03816
# [216]	validation_0-logloss:0.03816
# [217]	validation_0-logloss:0.03815
# [218]	validation_0-logloss:0.03815
# [219]	validation_0-logloss:0.03815
# [220]	validation_0-logloss:0.03815
# [221]	validation_0-logloss:0.03815
# [222]	validation_0-logloss:0.03814
# [223]	validation_0-logloss:0.03814
# [224]	validation_0-logloss:0.03814
# [225]	validation_0-logloss:0.03814
# [226]	validation_0-logloss:0.03814
# [227]	validation_0-logloss:0.03813
# [228]	validation_0-logloss:0.03813
# [229]	validation_0-logloss:0.03813
# [230]	validation_0-logloss:0.03813
# [231]	validation_0-logloss:0.03812
# [232]	validation_0-logloss:0.03812
# [233]	validation_0-logloss:0.03811
# [234]	validation_0-logloss:0.03811
# [235]	validation_0-logloss:0.03811
# [236]	validation_0-logloss:0.03811
# [237]	validation_0-logloss:0.03811
# [238]	validation_0-logloss:0.03811
# [239]	validation_0-logloss:0.03811
# [240]	validation_0-logloss:0.03811
# [241]	validation_0-logloss:0.03811
# [242]	validation_0-logloss:0.03811
# [243]	validation_0-logloss:0.03810
# [244]	validation_0-logloss:0.03810
# [245]	validation_0-logloss:0.03810
# [246]	validation_0-logloss:0.03810
# [247]	validation_0-logloss:0.03810
# [248]	validation_0-logloss:0.03810
# [249]	validation_0-logloss:0.03811
# [250]	validation_0-logloss:0.03810
# [251]	validation_0-logloss:0.03810
# [252]	validation_0-logloss:0.03810
# [253]	validation_0-logloss:0.03810
# [254]	validation_0-logloss:0.03810
# [255]	validation_0-logloss:0.03810
# [256]	validation_0-logloss:0.03810
# [257]	validation_0-logloss:0.03810
# [258]	validation_0-logloss:0.03810
# [259]	validation_0-logloss:0.03809
# [260]	validation_0-logloss:0.03809
# [261]	validation_0-logloss:0.03810
# [262]	validation_0-logloss:0.03810
# [263]	validation_0-logloss:0.03810
# [264]	validation_0-logloss:0.03810
# [265]	validation_0-logloss:0.03810
# [266]	validation_0-logloss:0.03810
# [267]	validation_0-logloss:0.03810
# [268]	validation_0-logloss:0.03810
# [269]	validation_0-logloss:0.03810
# [270]	validation_0-logloss:0.03810
# [271]	validation_0-logloss:0.03810
# [272]	validation_0-logloss:0.03810
# [273]	validation_0-logloss:0.03810
# [274]	validation_0-logloss:0.03810
# [275]	validation_0-logloss:0.03810
# [276]	validation_0-logloss:0.03810
# [277]	validation_0-logloss:0.03810
# [278]	validation_0-logloss:0.03810
# [279]	validation_0-logloss:0.03810
# [280]	validation_0-logloss:0.03810
# [281]	validation_0-logloss:0.03810
# [282]	validation_0-logloss:0.03809
# [283]	validation_0-logloss:0.03809
# [284]	validation_0-logloss:0.03809
# [285]	validation_0-logloss:0.03809
# [286]	validation_0-logloss:0.03809
# [287]	validation_0-logloss:0.03809
# [288]	validation_0-logloss:0.03809
# [289]	validation_0-logloss:0.03810
# [290]	validation_0-logloss:0.03810
# [291]	validation_0-logloss:0.03810
# [292]	validation_0-logloss:0.03810
# [293]	validation_0-logloss:0.03810
# [294]	validation_0-logloss:0.03810
# [295]	validation_0-logloss:0.03810
# [296]	validation_0-logloss:0.03810
# [297]	validation_0-logloss:0.03810
# [298]	validation_0-logloss:0.03811
# [299]	validation_0-logloss:0.03811
# 4it [01:13, 18.34s/it]
# [0]	validation_0-logloss:0.63823
# [1]	validation_0-logloss:0.58486
# [2]	validation_0-logloss:0.54247
# [3]	validation_0-logloss:0.51626
# [4]	validation_0-logloss:0.48221
# [5]	validation_0-logloss:0.45552
# [6]	validation_0-logloss:0.44099
# [7]	validation_0-logloss:0.40938
# [8]	validation_0-logloss:0.38307
# [9]	validation_0-logloss:0.35550
# [10]	validation_0-logloss:0.34060
# [11]	validation_0-logloss:0.31849
# [12]	validation_0-logloss:0.29837
# [13]	validation_0-logloss:0.28034
# [14]	validation_0-logloss:0.27070
# [15]	validation_0-logloss:0.25655
# [16]	validation_0-logloss:0.24670
# [17]	validation_0-logloss:0.23699
# [18]	validation_0-logloss:0.22755
# [19]	validation_0-logloss:0.21917
# [20]	validation_0-logloss:0.21054
# [21]	validation_0-logloss:0.19916
# [22]	validation_0-logloss:0.18804
# [23]	validation_0-logloss:0.18163
# [24]	validation_0-logloss:0.17169
# [25]	validation_0-logloss:0.16459
# [26]	validation_0-logloss:0.16048
# [27]	validation_0-logloss:0.15166
# [28]	validation_0-logloss:0.14572
# [29]	validation_0-logloss:0.14130
# [30]	validation_0-logloss:0.13461
# [31]	validation_0-logloss:0.13146
# [32]	validation_0-logloss:0.12496
# [33]	validation_0-logloss:0.12113
# [34]	validation_0-logloss:0.11800
# [35]	validation_0-logloss:0.11263
# [36]	validation_0-logloss:0.10904
# [37]	validation_0-logloss:0.10482
# [38]	validation_0-logloss:0.10089
# [39]	validation_0-logloss:0.09784
# [40]	validation_0-logloss:0.09436
# [41]	validation_0-logloss:0.09146
# [42]	validation_0-logloss:0.08790
# [43]	validation_0-logloss:0.08515
# [44]	validation_0-logloss:0.08366
# [45]	validation_0-logloss:0.08188
# [46]	validation_0-logloss:0.08057
# [47]	validation_0-logloss:0.07780
# [48]	validation_0-logloss:0.07564
# [49]	validation_0-logloss:0.07340
# [50]	validation_0-logloss:0.07175
# [51]	validation_0-logloss:0.06941
# [52]	validation_0-logloss:0.06720
# [53]	validation_0-logloss:0.06622
# [54]	validation_0-logloss:0.06456
# [55]	validation_0-logloss:0.06349
# [56]	validation_0-logloss:0.06265
# [57]	validation_0-logloss:0.06131
# [58]	validation_0-logloss:0.06034
# [59]	validation_0-logloss:0.05970
# [60]	validation_0-logloss:0.05898
# [61]	validation_0-logloss:0.05822
# [62]	validation_0-logloss:0.05744
# [63]	validation_0-logloss:0.05661
# [64]	validation_0-logloss:0.05568
# [65]	validation_0-logloss:0.05474
# [66]	validation_0-logloss:0.05414
# [67]	validation_0-logloss:0.05327
# [68]	validation_0-logloss:0.05248
# [69]	validation_0-logloss:0.05155
# [70]	validation_0-logloss:0.05117
# [71]	validation_0-logloss:0.05077
# [72]	validation_0-logloss:0.05014
# [73]	validation_0-logloss:0.04966
# [74]	validation_0-logloss:0.04921
# [75]	validation_0-logloss:0.04882
# [76]	validation_0-logloss:0.04806
# [77]	validation_0-logloss:0.04743
# [78]	validation_0-logloss:0.04694
# [79]	validation_0-logloss:0.04662
# [80]	validation_0-logloss:0.04618
# [81]	validation_0-logloss:0.04558
# [82]	validation_0-logloss:0.04524
# [83]	validation_0-logloss:0.04492
# [84]	validation_0-logloss:0.04456
# [85]	validation_0-logloss:0.04418
# [86]	validation_0-logloss:0.04382
# [87]	validation_0-logloss:0.04360
# [88]	validation_0-logloss:0.04345
# [89]	validation_0-logloss:0.04321
# [90]	validation_0-logloss:0.04283
# [91]	validation_0-logloss:0.04259
# [92]	validation_0-logloss:0.04234
# [93]	validation_0-logloss:0.04207
# [94]	validation_0-logloss:0.04194
# [95]	validation_0-logloss:0.04176
# [96]	validation_0-logloss:0.04158
# [97]	validation_0-logloss:0.04128
# [98]	validation_0-logloss:0.04118
# [99]	validation_0-logloss:0.04108
# [100]	validation_0-logloss:0.04090
# [101]	validation_0-logloss:0.04076
# [102]	validation_0-logloss:0.04064
# [103]	validation_0-logloss:0.04051
# [104]	validation_0-logloss:0.04039
# [105]	validation_0-logloss:0.04026
# [106]	validation_0-logloss:0.04013
# [107]	validation_0-logloss:0.03999
# [108]	validation_0-logloss:0.03989
# [109]	validation_0-logloss:0.03976
# [110]	validation_0-logloss:0.03968
# [111]	validation_0-logloss:0.03959
# [112]	validation_0-logloss:0.03945
# [113]	validation_0-logloss:0.03937
# [114]	validation_0-logloss:0.03924
# [115]	validation_0-logloss:0.03914
# [116]	validation_0-logloss:0.03909
# [117]	validation_0-logloss:0.03898
# [118]	validation_0-logloss:0.03892
# [119]	validation_0-logloss:0.03890
# [120]	validation_0-logloss:0.03886
# [121]	validation_0-logloss:0.03883
# [122]	validation_0-logloss:0.03880
# [123]	validation_0-logloss:0.03875
# [124]	validation_0-logloss:0.03866
# [125]	validation_0-logloss:0.03857
# [126]	validation_0-logloss:0.03853
# [127]	validation_0-logloss:0.03850
# [128]	validation_0-logloss:0.03847
# [129]	validation_0-logloss:0.03841
# [130]	validation_0-logloss:0.03839
# [131]	validation_0-logloss:0.03832
# [132]	validation_0-logloss:0.03830
# [133]	validation_0-logloss:0.03828
# [134]	validation_0-logloss:0.03825
# [135]	validation_0-logloss:0.03819
# [136]	validation_0-logloss:0.03814
# [137]	validation_0-logloss:0.03811
# [138]	validation_0-logloss:0.03809
# [139]	validation_0-logloss:0.03807
# [140]	validation_0-logloss:0.03803
# [141]	validation_0-logloss:0.03800
# [142]	validation_0-logloss:0.03796
# [143]	validation_0-logloss:0.03794
# [144]	validation_0-logloss:0.03789
# [145]	validation_0-logloss:0.03788
# [146]	validation_0-logloss:0.03786
# [147]	validation_0-logloss:0.03781
# [148]	validation_0-logloss:0.03777
# [149]	validation_0-logloss:0.03775
# [150]	validation_0-logloss:0.03772
# [151]	validation_0-logloss:0.03769
# [152]	validation_0-logloss:0.03766
# [153]	validation_0-logloss:0.03765
# [154]	validation_0-logloss:0.03764
# [155]	validation_0-logloss:0.03762
# [156]	validation_0-logloss:0.03759
# [157]	validation_0-logloss:0.03757
# [158]	validation_0-logloss:0.03755
# [159]	validation_0-logloss:0.03752
# [160]	validation_0-logloss:0.03751
# [161]	validation_0-logloss:0.03749
# [162]	validation_0-logloss:0.03749
# [163]	validation_0-logloss:0.03747
# [164]	validation_0-logloss:0.03745
# [165]	validation_0-logloss:0.03743
# [166]	validation_0-logloss:0.03742
# [167]	validation_0-logloss:0.03741
# [168]	validation_0-logloss:0.03740
# [169]	validation_0-logloss:0.03739
# [170]	validation_0-logloss:0.03738
# [171]	validation_0-logloss:0.03736
# [172]	validation_0-logloss:0.03736
# [173]	validation_0-logloss:0.03735
# [174]	validation_0-logloss:0.03734
# [175]	validation_0-logloss:0.03733
# [176]	validation_0-logloss:0.03732
# [177]	validation_0-logloss:0.03732
# [178]	validation_0-logloss:0.03732
# [179]	validation_0-logloss:0.03731
# [180]	validation_0-logloss:0.03730
# [181]	validation_0-logloss:0.03729
# [182]	validation_0-logloss:0.03729
# [183]	validation_0-logloss:0.03729
# [184]	validation_0-logloss:0.03728
# [185]	validation_0-logloss:0.03727
# [186]	validation_0-logloss:0.03727
# [187]	validation_0-logloss:0.03726
# [188]	validation_0-logloss:0.03725
# [189]	validation_0-logloss:0.03725
# [190]	validation_0-logloss:0.03724
# [191]	validation_0-logloss:0.03724
# [192]	validation_0-logloss:0.03723
# [193]	validation_0-logloss:0.03723
# [194]	validation_0-logloss:0.03722
# [195]	validation_0-logloss:0.03722
# [196]	validation_0-logloss:0.03721
# [197]	validation_0-logloss:0.03720
# [198]	validation_0-logloss:0.03719
# [199]	validation_0-logloss:0.03718
# [200]	validation_0-logloss:0.03718
# [201]	validation_0-logloss:0.03718
# [202]	validation_0-logloss:0.03718
# [203]	validation_0-logloss:0.03717
# [204]	validation_0-logloss:0.03717
# [205]	validation_0-logloss:0.03716
# [206]	validation_0-logloss:0.03715
# [207]	validation_0-logloss:0.03715
# [208]	validation_0-logloss:0.03714
# [209]	validation_0-logloss:0.03714
# [210]	validation_0-logloss:0.03714
# [211]	validation_0-logloss:0.03713
# [212]	validation_0-logloss:0.03712
# [213]	validation_0-logloss:0.03712
# [214]	validation_0-logloss:0.03711
# [215]	validation_0-logloss:0.03711
# [216]	validation_0-logloss:0.03711
# [217]	validation_0-logloss:0.03711
# [218]	validation_0-logloss:0.03710
# [219]	validation_0-logloss:0.03710
# [220]	validation_0-logloss:0.03709
# [221]	validation_0-logloss:0.03709
# [222]	validation_0-logloss:0.03709
# [223]	validation_0-logloss:0.03709
# [224]	validation_0-logloss:0.03708
# [225]	validation_0-logloss:0.03708
# [226]	validation_0-logloss:0.03708
# [227]	validation_0-logloss:0.03708
# [228]	validation_0-logloss:0.03707
# [229]	validation_0-logloss:0.03706
# [230]	validation_0-logloss:0.03706
# [231]	validation_0-logloss:0.03705
# [232]	validation_0-logloss:0.03705
# [233]	validation_0-logloss:0.03705
# [234]	validation_0-logloss:0.03704
# [235]	validation_0-logloss:0.03704
# [236]	validation_0-logloss:0.03704
# [237]	validation_0-logloss:0.03703
# [238]	validation_0-logloss:0.03703
# [239]	validation_0-logloss:0.03703
# [240]	validation_0-logloss:0.03702
# [241]	validation_0-logloss:0.03702
# [242]	validation_0-logloss:0.03702
# [243]	validation_0-logloss:0.03702
# [244]	validation_0-logloss:0.03702
# [245]	validation_0-logloss:0.03702
# [246]	validation_0-logloss:0.03702
# [247]	validation_0-logloss:0.03702
# [248]	validation_0-logloss:0.03701
# [249]	validation_0-logloss:0.03701
# [250]	validation_0-logloss:0.03701
# [251]	validation_0-logloss:0.03701
# [252]	validation_0-logloss:0.03701
# [253]	validation_0-logloss:0.03701
# [254]	validation_0-logloss:0.03701
# [255]	validation_0-logloss:0.03700
# [256]	validation_0-logloss:0.03700
# [257]	validation_0-logloss:0.03700
# [258]	validation_0-logloss:0.03700
# [259]	validation_0-logloss:0.03700
# [260]	validation_0-logloss:0.03700
# [261]	validation_0-logloss:0.03700
# [262]	validation_0-logloss:0.03700
# [263]	validation_0-logloss:0.03700
# [264]	validation_0-logloss:0.03700
# [265]	validation_0-logloss:0.03700
# [266]	validation_0-logloss:0.03700
# [267]	validation_0-logloss:0.03700
# [268]	validation_0-logloss:0.03700
# [269]	validation_0-logloss:0.03700
# [270]	validation_0-logloss:0.03700
# [271]	validation_0-logloss:0.03699
# [272]	validation_0-logloss:0.03700
# [273]	validation_0-logloss:0.03699
# [274]	validation_0-logloss:0.03699
# [275]	validation_0-logloss:0.03699
# [276]	validation_0-logloss:0.03699
# [277]	validation_0-logloss:0.03699
# [278]	validation_0-logloss:0.03699
# [279]	validation_0-logloss:0.03699
# [280]	validation_0-logloss:0.03699
# [281]	validation_0-logloss:0.03699
# [282]	validation_0-logloss:0.03698
# [283]	validation_0-logloss:0.03698
# [284]	validation_0-logloss:0.03698
# [285]	validation_0-logloss:0.03698
# [286]	validation_0-logloss:0.03698
# [287]	validation_0-logloss:0.03698
# [288]	validation_0-logloss:0.03698
# [289]	validation_0-logloss:0.03698
# [290]	validation_0-logloss:0.03698
# [291]	validation_0-logloss:0.03698
# [292]	validation_0-logloss:0.03698
# [293]	validation_0-logloss:0.03698
# [294]	validation_0-logloss:0.03698
# [295]	validation_0-logloss:0.03698
# [296]	validation_0-logloss:0.03698
# [297]	validation_0-logloss:0.03699
# [298]	validation_0-logloss:0.03698
# [299]	validation_0-logloss:0.03698
# 5it [01:31, 18.38s/it]
# Validation mcc score: 0.9835346920598655

# %%
submit_df = pd.DataFrame()
submit_df["id"] = test["id"]
y_preds = clf.predict(X_test_transformed)
pred_classes = lb.inverse_transform(y_preds)
submit_df["class"] = pred_classes
submit_df.to_csv("submission.csv", index=False)
